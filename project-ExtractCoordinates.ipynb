# %% [markdown]
# #Table of Contents
# * [1. Web Scraping](#1.-Web-Scraping)
# * [2. Filbert checking data](#2.-Filbert-checking-data)
# * [3. Filbert: run from here onwards](#3.-Filbert:-run-from-here-onwards)

# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline
# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import json
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
import random

# %%
from pyquery import PyQuery as pq
from bs4 import BeautifulSoup
# The "requests" library makes working with HTTP requests easier
# than the built-in urllib libraries.
import requests

# %% [markdown]
# #2. Filbert checking data

# %%
citiesraw = []
citiesfile = open('tempdata/cities1000.txt', 'r')
#citiesfile.readline()
while 1:
    line = citiesfile.readline()
    if not line:
        break
    citiesraw.append(line)

# %%
#Use largest population to resolve conflict
print len(citiesraw)
print citiesraw[1]
print citiesraw[1].split('\t')

#coordinatesdict = {}
#for x in range(len(citiesraw)):
#for x in range(10):
#    templist = citiesraw[x].split('\t')
#    coordinatesdict[templist[1].lower()] = (templist[4],templist[5])
    
coordinatesdict = {}
duplicatecities = {}
for x in range(len(citiesraw)):
#for x in range(10):
    templist = citiesraw[x].split('\t')
    cityname = templist[1].lower()
    if cityname not in coordinatesdict:
        coordinatesdict[templist[1].lower()] = (templist[4],templist[5])
        duplicatecities[cityname]=templist[14]
    else:
        if templist[14] < duplicatecities[cityname]:
            duplicatecities[cityname]=templist[14]
            coordinatesdict[templist[1].lower()] = (templist[4],templist[5])
    if x%1000 == 0:
        print x
# Out:
# 145493
# 3039163	Sant Julià de Lòria	Sant Julia de Loria	San Julia,San Julià,Sant Julia de Loria,Sant Julià de Lòria,Sant-Zhulija-de-Lorija,sheng hu li ya-de luo li ya,Сант-Жулия-де-Лория,サン・ジュリア・デ・ロリア教区,圣胡利娅-德洛里亚,圣胡利娅－德洛里亚	42.46372	1.49129	P	PPLA	AD		06				8022		921	Europe/Andorra	2013-11-23
#
# ['3039163', 'Sant Juli\xc3\xa0 de L\xc3\xb2ria', 'Sant Julia de Loria', 'San Julia,San Juli\xc3\xa0,Sant Julia de Loria,Sant Juli\xc3\xa0 de L\xc3\xb2ria,Sant-Zhulija-de-Lorija,sheng hu li ya-de luo li ya,\xd0\xa1\xd0\xb0\xd0\xbd\xd1\x82-\xd0\x96\xd1\x83\xd0\xbb\xd0\xb8\xd1\x8f-\xd0\xb4\xd0\xb5-\xd0\x9b\xd0\xbe\xd1\x80\xd0\xb8\xd1\x8f,\xe3\x82\xb5\xe3\x83\xb3\xe3\x83\xbb\xe3\x82\xb8\xe3\x83\xa5\xe3\x83\xaa\xe3\x82\xa2\xe3\x83\xbb\xe3\x83\x87\xe3\x83\xbb\xe3\x83\xad\xe3\x83\xaa\xe3\x82\xa2\xe6\x95\x99\xe5\x8c\xba,\xe5\x9c\xa3\xe8\x83\xa1\xe5\x88\xa9\xe5\xa8\x85-\xe5\xbe\xb7\xe6\xb4\x9b\xe9\x87\x8c\xe4\xba\x9a,\xe5\x9c\xa3\xe8\x83\xa1\xe5\x88\xa9\xe5\xa8\x85\xef\xbc\x8d\xe5\xbe\xb7\xe6\xb4\x9b\xe9\x87\x8c\xe4\xba\x9a', '42.46372', '1.49129', 'P', 'PPLA', 'AD', '', '06', '', '', '', '8022', '', '921', 'Europe/Andorra', '2013-11-23\n']
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
stateslist = [state.lower() for state in states.values()]
print len(coordinatesdict)
for state in stateslist:
    if state in coordinatesdict:
        del coordinatesdict[state]
print len(coordinatesdict)

del coordinatesdict['uk']
# Out:
# 125626
# 125610

# %%
import codecs
cities2raw = []
with codecs.open('tempdata/CountriesToCities.json', 'r', encoding= "UTF-16") as f:
    for line in f:
       cities2raw.append(json.loads(line))

# %%
countries = [item.lower() for item in cities2raw[0].keys()]

# %%
print len(coordinatesdict)
for country in countries:
    if country in coordinatesdict:
        del coordinatesdict[country]
print len(coordinatesdict)
# Out:
# 125609
# 125561

# %%
------------------------
# Out:
#   File "<ipython-input-10-3f7476060c5b>", line 1
#     ------------------------
#                             ^
# SyntaxError: invalid syntax

# %%
df = pd.read_json("tempdata/movieinfo_2014_full.json")
df = df.append(pd.read_json("tempdata/movieinfo_2013.json"))
df = df.append(pd.read_json("tempdata/movieinfo_2012.json"))
df = df.append(pd.read_json("tempdata/movieinfo_2011.json"))
df = df.append(pd.read_json("tempdata/movieinfo_2010.json"))
df = df.append(pd.read_json("tempdata/movieinfo_2009.json"))

# %%
r_df = df[~df["user_ratings"].isnull()].reset_index()

# %%
len(r_df)
# Out:
# 32788

# %%
new_df = r_df[r_df["location_page"]!="None"].reset_index()
new_df
# Out:
#        level_0  index       budget contentRating     country critic_ratings duration                           genre        gross    language                                      location_page                                         name opening_weekend                     release_dates                url  user_ratings user_ratings_count  year
# 0            0      0   €1,500,000           NaN  Kazakhstan            NaN  110 min                         [Drama]          NaN     Russian  [Minsk, Belarus , Almaty, Kazakhstan , St. Pet...                                 Ya ne vernus             NaN         [ 1 March 2014 (Russia) ]  /title/tt2637844/           6.9                320  2014
# 1            2      3          NaN           NaN         USA            NaN   85 min     [Horror, Mystery, Thriller]          NaN     English                             [Silt, Colorado, USA ]                                      Find Me             NaN        [ 1 September 2014 (USA) ]  /title/tt3027188/           4.5                649  2014
# 2            3      4          NaN           NaN     Ireland            NaN   88 min         [Comedy, Drama, Family]          NaN     English  [Dublin, County Dublin, Ireland , County Wickl...                                         Gold             NaN     [ 10 October 2014 (Ireland) ]  /title/tt3134422/           6.1                406  2014
# 3            7     10          NaN           Not         USA            NaN   85 min      [Action, Sci-Fi, Thriller]          NaN     English  [Los Angeles, California, USA , Long Beach, Ca...                   Mega Shark vs. Mecha Shark             NaN         [ 28 January 2014 (USA) ]  /title/tt3152098/           2.6              1,988  2014
# 4            8     11          NaN           NaN      Poland            NaN  117 min                [Drama, Romance]          NaN      Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                                   Obce cialo             NaN      [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014
# 5           12     19      $50,000           NaN         USA            NaN      NaN                        [Comedy]          NaN     English  [Angelus Oaks, California, USA , California, U...                                     Camp-Off             NaN            [ 4 April 2014 (USA) ]  /title/tt3482042/           7.3                  7  2014
# 6           14     21          NaN           NaN     Germany            NaN   84 min                 [Comedy, Drama]          NaN      German  [Akademie der Künste, Berlin, Germany , Haus d...       Ich will mich nicht künstlich aufregen             NaN       [ February 2014 (Germany) ]  /title/tt3471498/           6.2                 28  2014
# 7           15     23          NaN           NaN      Sweden            NaN   99 min          [Action, Crime, Drama]          NaN     Swedish  [Falkenberg, Hallands län, Sweden , Uddevalla,...                                   Svart kung             NaN        [ 15 March 2014 (Sweden) ]  /title/tt2935416/           6.2                 42  2014
# 8           16     24       $7,100           NaN         USA            NaN   92 min                        [Action]          NaN     English  [New York, USA , Paulsboro, New Jersey, USA , ...                                       Battle             NaN        [ 25 December 2014 (USA) ]  /title/tt2094769/           6.6                  8  2014
# 9           20     29          NaN           NaN          UK            NaN   90 min                        [Horror]          NaN     English                                       [Wales, UK ]                          Valley of the Witch             NaN         [ 13 January 2015 (USA) ]  /title/tt2908340/           5.0                 67  2014
# 10          24     35          NaN           NaN         USA            NaN      NaN       [Action, Family, Fantasy]          NaN     English                           [Denver, Colorado, USA ]                          Legacy of the Tengu             NaN              [ 1 May 2014 (USA) ]  /title/tt1874742/           5.4                 11  2014
# 11          25     36          NaN           NaN       Chile            NaN   90 min         [Action, Comedy, Crime]          NaN     Spanish                                 [Santiago, Chile ]                            Santiago Violenta             NaN        [ 1 January 2015 (Chile) ]  /title/tt2128535/           6.4                 70  2014
# 12          28     44          NaN           NaN      France            NaN  118 min     [Biography, Drama, Fantasy]          NaN     English                                [Lisbon, Portugal ]                          Casanova Variations             NaN                    [ 2015 (USA) ]  /title/tt2614400/           6.2                122  2014
# 13          35     51       $3,000           NaN         USA            NaN   75 min                        [Horror]          NaN     English  [Marquam, Oregon, USA , Silverton, Oregon, USA...                                      Drifter             NaN             [ 23 May 2014 (USA) ]  /title/tt3143384/           5.8                  6  2014
# 14          38     57          NaN           NaN       China            NaN      NaN                     [Animation]          NaN     Chinese                                           [China ]         Bai Xue Gong Zhu Zhi Ai Ren Li Liang             NaN                    [ 2015 (USA) ]  /title/tt3973682/           3.8                  6  2014
# 15          39     58          NaN           NaN     Germany            NaN  106 min                [Drama, Romance]          NaN      German  [Cologne, North Rhine-Westphalia, Germany , In...                                     Der Koch             NaN    [ 27 November 2014 (Germany) ]  /title/tt3106212/           5.4                 77  2014
# 16          40     59      $70,000             R         USA         70/100   82 min                 [Comedy, Drama]      $30,084     English                          [Chicago, Illinois, USA ]                              Happy Christmas          $7,523            [ 26 June 2014 (USA) ]  /title/tt2955096/           5.6              4,832  2014
# 17          43     64          NaN           NaN     Germany            NaN   95 min                        [Comedy]          NaN      German              [Frankfurt am Main, Hessen, Germany ]                                 Doktorspiele             NaN      [ 28 August 2014 (Germany) ]  /title/tt3328720/           5.5                577  2014
# 18          46     68          NaN           NaN       India            NaN      NaN      [Comedy, Horror, Thriller]          NaN      Telugu                     [Hyderabad, Telangana, India ]                                      The End             NaN      [ 15 November 2014 (India) ]  /title/tt4202974/           5.2                 11  2014
# 19          51     74          NaN           NaN         USA            NaN   62 min                 [Drama, Family]          NaN     English  [Springfield, Tennessee, USA , Destin, Florida...                                The Good Book             NaN             [ 1 July 2014 (USA) ]  /title/tt3034546/           6.8                 16  2014
# 20          53     76          NaN             R         USA         76/100  100 min             [Mystery, Thriller]     $322,600     English  [Moriarty, New Mexico, USA , Estancia, New Mex...                                    The Guest         $84,527         [ 5 September 2014 (UK) ]  /title/tt2980592/           6.7             55,000  2014
# 21          54     80          NaN            PG         USA         53/100   95 min     [Biography, Drama, History]          NaN     English  [Mohonk Preserve, New Paltz, New York, USA , A...                            The Better Angels             NaN         [ 7 November 2014 (USA) ]  /title/tt2316868/           6.1                853  2014
# 22          56     83          NaN           NaN       Japan            NaN  117 min                        [Comedy]          NaN    Japanese                                 [Hokkaido, Japan ]                               Budô no namida             NaN       [ 11 October 2014 (Japan) ]  /title/tt3198994/           6.2                 24  2014
# 23          57     84          INR           NaN       India            NaN  140 min        [Action, Drama, Romance]          NaN     Bengali            [Kolkata, West Bengal, India , Turkey ]                                      Borbaad             NaN        [ 15 August 2014 (India) ]  /title/tt3958596/           5.5                 71  2014
# 24          61     94          NaN           Not          UK         75/100  108 min                 [Comedy, Drama]   $2,873,758     English                                           [Italy ]                            The Trip to Italy         $71,712            [ 25 April 2014 (UK) ]  /title/tt2967006/           6.6              9,834  2014
# 25          63     97          NaN           NaN         USA            NaN   89 min                        [Comedy]          NaN     English                                             [USA ]                                Chasing Taste             NaN                                []  /title/tt2997704/           7.5                 11  2014
# 26          64     98          NaN           NaN      Sweden            NaN   90 min                      [Thriller]          NaN     Swedish  [Båstad, Skåne län, Sweden , Malmö, Skåne län,...                                    Inbrottet             NaN          [ 22 May 2014 (Sweden) ]  /title/tt3061610/           8.3                  6  2014
# 27          66    101   $9,000,000             R         USA         50/100  103 min        [Action, Horror, Sci-Fi]  $71,519,230     English  [Los Angeles, California, USA , Chip's Restaur...                           The Purge: Anarchy     $29,816,675            [ 18 July 2014 (USA) ]  /title/tt2975578/           6.5             75,998  2014
# 28          75    112          NaN           NaN      France            NaN   88 min     [Fantasy, Sci-Fi, Thriller]          NaN      French                                          [France ]                  Léa, un ange dans ma maison             NaN      [ 21 January 2015 (France) ]  /title/tt3746666/           7.1                 23  2014
# 29          78    117          NaN           NaN         USA         34/100   92 min               [Comedy, Romance]          NaN     English  [Tampa, Florida, USA , Lakeland, Florida, USA ...                                       Sex Ed             NaN         [ 7 November 2014 (USA) ]  /title/tt2751310/           5.6              3,021  2014
# ...        ...    ...          ...           ...         ...            ...      ...                             ...          ...         ...                                                ...                                          ...             ...                               ...                ...           ...                ...   ...
# 18001    32745   6709          NaN             R          UK            NaN   86 min        [Action, Comedy, Horror]   £1,581,373     English  [Luton Hoo Estate, Luton, Bedfordshire, Englan...                              Vampire Killers        £648,634            [ 20 March 2009 (UK) ]  /title/tt1020885/           5.2             16,688  2009
# 18002    32747   6712          NaN           NaN         USA            NaN   74 min                         [Drama]          NaN     English  [Half Moon Bay, California, USA , South Lake T...                            Sex and Imagining             NaN                                []  /title/tt1493165/           8.0                 20  2009
# 18003    32748   6713          NaN           NaN     Germany            NaN   81 min                              []          NaN      German  [Dresden, Saxony, Germany , Jena, Thuringia, G...                                  Unter Strom             NaN    [ 10 December 2009 (Germany) ]  /title/tt0304876/           5.4                 72  2009
# 18004    32749   6714          NaN           NaN      France            NaN   99 min                      [Thriller]          NaN      French                                   [Paris, France ]                           Une affaire d'état             NaN     [ 25 November 2009 (France) ]  /title/tt1282156/           6.3                435  2009
# 18005    32751   6717   $6,000,000         PG-13         USA         66/100  104 min                 [Comedy, Drama]   $6,670,712     English  [City Island, Bronx, New York City, New York, ...                                  City Island         $32,001           [ 30 April 2010 (USA) ]  /title/tt1174730/           7.4             26,601  2009
# 18006    32752   6718          NaN           NaN   Argentina            NaN  115 min                [Biography, War]          NaN     Spanish  [Chaco, Argentina , Formosa, Argentina , San J...                Fontana, la frontera interior             NaN   [ 20 October 2011 (Argentina) ]  /title/tt1615843/           6.3                  7  2009
# 18007    32753   6721          NaN           NaN         USA            NaN   78 min                              []          NaN         NaN                  [San Francisco, California, USA ]                                      Rebound             NaN                                []  /title/tt1479780/           6.2                 17  2009
# 18008    32754   6722          NaN           NaN      Turkey            NaN      NaN                         [Drama]          NaN     Turkish                               [Eskisehir, Turkey ]                                 Yengeç oyunu             NaN         [ 3 April 2009 (Turkey) ]  /title/tt1399231/           4.2                 78  2009
# 18009    32755   6723          NaN           NaN   Australia            NaN   88 min              [Horror, Thriller]          NaN     English  [Melbourne, Victoria, Australia , Sydney, New ...                                     Fragment             NaN              [ 2009 (Australia) ]  /title/tt0973836/           3.6                156  2009
# 18010    32756   6724          NaN           NaN     Hungary            NaN   90 min                 [Comedy, Drama]          NaN   Hungarian                    [Constanta, Romania , Romania ]                                         Adás             NaN      [ 7 January 2010 (Hungary) ]  /title/tt1366245/           5.4                 94  2009
# 18011    32757   6725          BGL           NaN    Bulgaria            NaN   90 min                         [Drama]          NaN   Bulgarian                                        [Bulgaria ]                              Durvenoto ezero             NaN  [ 30 September 2009 (Bulgaria) ]  /title/tt1828175/           5.5                  8  2009
# 18012    32758   6726          NaN           NaN       India            NaN      NaN                 [Comedy, Drama]          NaN       Hindi  [Himachal Pradesh, India , Mumbai, Maharashtra...                                    Chintu Ji             NaN      [ 4 September 2009 (India) ]  /title/tt1135931/           5.7                148  2009
# 18013    32759   6728          NaN           NaN         USA            NaN   70 min        [Comedy, Drama, Mystery]          NaN     English  [Minneapolis, Minnesota, USA , St. Louis Park,...                                         Bits             NaN                    [ 2009 (USA) ]  /title/tt1270083/           7.2                  8  2009
# 18014    32763   6732          NaN           NaN   Argentina            NaN   76 min                         [Drama]          NaN     Spanish                                   [Paris, France ]                                 77 Doronship             NaN        [ March 2009 (Argentina) ]  /title/tt1403041/           6.3                 38  2009
# 18015    32764   6733  $40,000,000            PG         USA         83/100   87 min  [Animation, Adventure, Comedy]  $20,999,103     English  [Three Mills Studios, Three Mill Lane, Bow, Lo...                            Fantastic Mr. Fox      £1,517,312        [ 25 November 2009 (USA) ]  /title/tt0432283/           7.8            128,303  2009
# 18016    32766   6736          NaN           NaN         USA            NaN   88 min                        [Horror]          NaN     English                           [Orlando, Florida, USA ]                                   Scare Zone             NaN                                []  /title/tt1380281/           5.7                 95  2009
# 18017    32767   6737          NaN           NaN      Canada            NaN   79 min                        [Comedy]          NaN     English  [Burkeville, British Columbia, Canada , Delta,...                      Underdogs: Born to Lose             NaN          [ 1 June 2009 (Canada) ]  /title/tt1414161/           3.0                  5  2009
# 18018    32769   6739   $3,500,000           NaN      Russia            NaN   84 min               [Comedy, Romance]          NaN     Russian    [New York City, New York, USA , New York, USA ]                      Lyubov v bolshom gorode             NaN         [ 5 March 2009 (Russia) ]  /title/tt1366687/           6.0              1,004  2009
# 18019    32770   6740     $250,000           NaN         USA            NaN   75 min                        [Horror]          NaN     English                    [Los Angeles, California, USA ]                                The Occultist             NaN         [ 30 October 2009 (USA) ]  /title/tt1508349/           3.5                 83  2009
# 18020    32771   6741          NaN           NaN   Argentina            NaN   89 min                      [Thriller]          NaN     Spanish       [Buenos Aires, Federal District, Argentina ]                               Matar a Videla             NaN    [ 7 January 2010 (Argentina) ]  /title/tt1560160/           3.9                 14  2009
# 18021    32774   6745          NaN           NaN     Germany            NaN   58 min                              []          NaN      German  [Erlangen, Bavaria, Germany , Hungary , Ljublj...                        Im Anhang: Lebenslauf             NaN     [ 27 January 2009 (Germany) ]  /title/tt1356793/           6.2                  5  2009
# 18022    32775   6746   $2,000,000             R      Canada            NaN   87 min        [Comedy, Drama, Romance]          NaN     English                        [Toronto, Ontario, Canada ]                                   Shark City             NaN         [ 1 November 2009 (USA) ]  /title/tt1055367/           4.1                200  2009
# 18023    32778   6750          NaN           NaN      France            NaN   90 min             [Adventure, Horror]          NaN      French                         [Aussois, Savoie, France ]                                    High Lane             NaN         [ 24 June 2009 (France) ]  /title/tt1433562/           5.6              5,471  2009
# 18024    32779   6751     $250,000           NaN         USA            NaN   95 min                         [Music]          NaN     English  [Los Angeles, California, USA , San Francisco,...  Otep Live Confrontation Concert Documentary             NaN             [ 1 July 2009 (USA) ]  /title/tt1469290/           5.8                  6  2009
# 18025    32780   6754          CAD           NaN      Canada            NaN   95 min                      [Thriller]          NaN      French  [Le Bic, Québec, Canada , Moncton, New Brunswi...                                       Détour             NaN    [ 18 September 2009 (Canada) ]  /title/tt1320343/           5.3                112  2009
# 18026    32781   6755          NaN           NaN   Indonesia            NaN   89 min                        [Horror]          NaN  Indonesian                           [Yogyakarta, Indonesia ]                                      Keramat             NaN  [ 3 September 2009 (Indonesia) ]  /title/tt1495818/           6.0                130  2009
# 18027    32784   6759  $30,000,000         PG-13         USA         60/100   79 min  [Animation, Action, Adventure]  $31,743,332     English  [Attitude Studios, Luxembourg, Luxembourg , Du...                                            9     $10,740,446        [ 9 September 2009 (USA) ]  /title/tt0472033/           7.1            105,281  2009
# 18028    32785   6760          NaN           NaN         USA            NaN   87 min                        [Comedy]          NaN     English         [Shanghai, China , Woodville, Texas, USA ]                                Made in China             NaN           [ 15 March 2009 (USA) ]  /title/tt1316064/           5.9                216  2009
# 18029    32786   6761     $500,000           NaN         USA         44/100   95 min                [Drama, Romance]      $11,276     English  [Brooklyn, New York City, New York, USA , Javi...                              Peter and Vandy          $7,323         [ 19 January 2009 (USA) ]  /title/tt1144551/           6.3              1,321  2009
# 18030    32787   6763          NaN           NaN     Germany            NaN   95 min        [Crime, Drama, Thriller]          NaN      German  [Stuttgart, Baden-Württemberg, Germany , Tangi...              Die zwei Leben des Daniel Shore             NaN    [ 11 February 2010 (Germany) ]  /title/tt1037230/           5.9                 85  2009
#
# [18031 rows x 18 columns]

# %%
len(new_df)
# Out:
# 18031

# %%
places = set()
places_freq = {}
separated_places = []
for row in new_df["location_page"]:
    temp = []
    for loc in row:
        split = loc.split(",")
        for item in split:
            stripped = item.encode('utf8').strip().lower()
            if stripped!="":
                places.add(stripped)
                temp.append(stripped)
                if stripped not in places_freq.keys():
                    places_freq[stripped] = 1
                places_freq[stripped] = places_freq[stripped] + 1
    separated_places.append(temp)
df_boolean = new_df.copy()
df_boolean['separated_places'] = separated_places

# %%
len(places)
# Out:
# 18983

# %%
places_freq = []
separated_places = []
for row in new_df["location_page"]:
    temp = []
    for loc in row:
        split = loc.split(",")
        for item in split:
            stripped = item.encode('utf8').strip().lower()
            if stripped!="":
                places.add(stripped)
                temp.append(stripped)
    separated_places.append(temp)
df_boolean = new_df.copy()
df_boolean['separated_places'] = separated_places

# %%
genreset = set()

for index, row in new_df.iterrows():
    genreslist = row.genre
    for genre in genreslist:
        genreset.add(genre.encode('utf8'))

# %%
print len(genreset)
genreset
# Out:
# 24
# {'Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %%
df_boolean.head()
# Out:
#    level_0  index      budget contentRating     country critic_ratings duration                        genre gross language                                      location_page                        name opening_weekend                  release_dates                url  user_ratings user_ratings_count  year                                   separated_places
# 0        0      0  €1,500,000           NaN  Kazakhstan            NaN  110 min                      [Drama]   NaN  Russian  [Minsk, Belarus , Almaty, Kazakhstan , St. Pet...                Ya ne vernus             NaN      [ 1 March 2014 (Russia) ]  /title/tt2637844/           6.9                320  2014  [minsk, belarus, almaty, kazakhstan, st. peter...
# 1        2      3         NaN           NaN         USA            NaN   85 min  [Horror, Mystery, Thriller]   NaN  English                             [Silt, Colorado, USA ]                     Find Me             NaN     [ 1 September 2014 (USA) ]  /title/tt3027188/           4.5                649  2014                              [silt, colorado, usa]
# 2        3      4         NaN           NaN     Ireland            NaN   88 min      [Comedy, Drama, Family]   NaN  English  [Dublin, County Dublin, Ireland , County Wickl...                        Gold             NaN  [ 10 October 2014 (Ireland) ]  /title/tt3134422/           6.1                406  2014  [dublin, county dublin, ireland, county wicklo...
# 3        7     10         NaN           Not         USA            NaN   85 min   [Action, Sci-Fi, Thriller]   NaN  English  [Los Angeles, California, USA , Long Beach, Ca...  Mega Shark vs. Mecha Shark             NaN      [ 28 January 2014 (USA) ]  /title/tt3152098/           2.6              1,988  2014  [los angeles, california, usa, long beach, cal...
# 4        8     11         NaN           NaN      Poland            NaN  117 min             [Drama, Romance]   NaN   Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                  Obce cialo             NaN   [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014  [ancona, marche, italy, warsaw, mazowieckie, p...

# %%
coordinateslist = []
coordinates_cities = []

for entry in df_boolean['separated_places']:


    coordinateslist.append([coordinatesdict[x] for x in entry if x in coordinatesdict])
    coordinates_cities.append([x for x in entry if x in coordinatesdict])


    
df_boolean['coordinates'] = coordinateslist
df_boolean['coordinates_cities'] = coordinates_cities

# %%
df_boolean.head()
# Out:
#    level_0  index      budget contentRating     country critic_ratings duration                        genre gross language                                      location_page                        name opening_weekend                  release_dates                url  user_ratings user_ratings_count  year                                   separated_places                                        coordinates         coordinates_cities
# 0        0      0  €1,500,000           NaN  Kazakhstan            NaN  110 min                      [Drama]   NaN  Russian  [Minsk, Belarus , Almaty, Kazakhstan , St. Pet...                Ya ne vernus             NaN      [ 1 March 2014 (Russia) ]  /title/tt2637844/           6.9                320  2014  [minsk, belarus, almaty, kazakhstan, st. peter...           [(53.9, 27.56667), (43.25654, 76.92848)]            [minsk, almaty]
# 1        2      3         NaN           NaN         USA            NaN   85 min  [Horror, Mystery, Thriller]   NaN  English                             [Silt, Colorado, USA ]                     Find Me             NaN     [ 1 September 2014 (USA) ]  /title/tt3027188/           4.5                649  2014                              [silt, colorado, usa]                           [(39.54859, -107.65617)]                     [silt]
# 2        3      4         NaN           NaN     Ireland            NaN   88 min      [Comedy, Drama, Family]   NaN  English  [Dublin, County Dublin, Ireland , County Wickl...                        Gold             NaN  [ 10 October 2014 (Ireland) ]  /title/tt3134422/           6.1                406  2014  [dublin, county dublin, ireland, county wicklo...                             [(53.33306, -6.24889)]                   [dublin]
# 3        7     10         NaN           Not         USA            NaN   85 min   [Action, Sci-Fi, Thriller]   NaN  English  [Los Angeles, California, USA , Long Beach, Ca...  Mega Shark vs. Mecha Shark             NaN      [ 28 January 2014 (USA) ]  /title/tt3152098/           2.6              1,988  2014  [los angeles, california, usa, long beach, cal...    [(34.05223, -118.24368), (41.73893, -86.85697)]  [los angeles, long beach]
# 4        8     11         NaN           NaN      Poland            NaN  117 min             [Drama, Romance]   NaN   Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                  Obce cialo             NaN   [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014  [ancona, marche, italy, warsaw, mazowieckie, p...  [(43.5942, 13.50337), (41.2381, -85.85305), (5...   [ancona, warsaw, moscow]

# %%
old_df = df_boolean.copy()
del old_df['coordinates']
del old_df['coordinates_cities']
new_df = pd.DataFrame(columns = df_boolean.columns)

# %%
old_df.head()
# Out:
#    level_0  index      budget contentRating     country critic_ratings duration                        genre gross language                                      location_page                        name opening_weekend                  release_dates                url  user_ratings user_ratings_count  year                                   separated_places
# 0        0      0  €1,500,000           NaN  Kazakhstan            NaN  110 min                      [Drama]   NaN  Russian  [Minsk, Belarus , Almaty, Kazakhstan , St. Pet...                Ya ne vernus             NaN      [ 1 March 2014 (Russia) ]  /title/tt2637844/           6.9                320  2014  [minsk, belarus, almaty, kazakhstan, st. peter...
# 1        2      3         NaN           NaN         USA            NaN   85 min  [Horror, Mystery, Thriller]   NaN  English                             [Silt, Colorado, USA ]                     Find Me             NaN     [ 1 September 2014 (USA) ]  /title/tt3027188/           4.5                649  2014                              [silt, colorado, usa]
# 2        3      4         NaN           NaN     Ireland            NaN   88 min      [Comedy, Drama, Family]   NaN  English  [Dublin, County Dublin, Ireland , County Wickl...                        Gold             NaN  [ 10 October 2014 (Ireland) ]  /title/tt3134422/           6.1                406  2014  [dublin, county dublin, ireland, county wicklo...
# 3        7     10         NaN           Not         USA            NaN   85 min   [Action, Sci-Fi, Thriller]   NaN  English  [Los Angeles, California, USA , Long Beach, Ca...  Mega Shark vs. Mecha Shark             NaN      [ 28 January 2014 (USA) ]  /title/tt3152098/           2.6              1,988  2014  [los angeles, california, usa, long beach, cal...
# 4        8     11         NaN           NaN      Poland            NaN  117 min             [Drama, Romance]   NaN   Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                  Obce cialo             NaN   [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014  [ancona, marche, italy, warsaw, mazowieckie, p...

# %%
#for x in range(len(old_df)):
flattencoordinates = []
flattencoordinatescities = []
newdfcounter = 0
print len(df_boolean)
for x in range(len(df_boolean)):
#for x in range(5):
    for y in range(len(df_boolean['coordinates'][x])):
        new_df.loc[newdfcounter] = old_df.iloc[x]
        flattencoordinates.append(df_boolean['coordinates'][x][y]) 
        flattencoordinatescities.append(df_boolean['coordinates_cities'][x][y]) 
        newdfcounter = newdfcounter + 1
    if x%100 == 0:
        print str(x) + "   " + str(newdfcounter)
new_df['coordinates'] = flattencoordinates
new_df['coordinates_cities'] = flattencoordinatescities
# Out:
# 18031
# 0   2
# 100   191
# 200   397
# 300   658
# 400   870
# 500   1128
# 600   1375
# 700   1632
# 800   1830
# 900   2029
# 1000   2218
# 1100   2463
# 1200   2700
# 1300   2960
# 1400   3195
# 1500   3461
# 1600   3718
# 1700   4008
# 1800   4223
# 1900   4461
# 2000   4741
# 2100   4919
# 2200   5165
# 2300   5365
# 2400   5610
# 2500   5819
# 2600   6019
# 2700   6247
# 2800   6478
# 2900   6687
# 3000   6913
# 3100   7136
# 3200   7396
# 3300   7654
# 3400   7881
# 3500   8140
# 3600   8341
# 3700   8587
# 3800   8805
# 3900   9019
# 4000   9286
# 4100   9512
# 4200   9755
# 4300   10053
# 4400   10317
# 4500   10499
# 4600   10697
# 4700   10939
# 4800   11175
# 4900   11440
# 5000   11647
# 5100   11896
# 5200   12075
# 5300   12313
# 5400   12532
# 5500   12762
# 5600   12994
# 5700   13194
# 5800   13506
# 5900   13765
# 6000   13978
# 6100   14237
# 6200   14483
# 6300   14729
# 6400   14957
# 6500   15184
# 6600   15465
# 6700   15689
# 6800   15920
# 6900   16194
# 7000   16401
# 7100   16646
# 7200   16877
# 7300   17156
# 7400   17391
# 7500   17637
# 7600   17920
# 7700   18136
# 7800   18348
# 7900   18610
# 8000   18874
# 8100   19103
# 8200   19319
# 8300   19528
# 8400   19721
# 8500   20000
# 8600   20193
# 8700   20431
# 8800   20669
# 8900   20922
# 9000   21202
# 9100   21413
# 9200   21626
# 9300   21926
# 9400   22148
# 9500   22396
# 9600   22678
# 9700   22900
# 9800   23122
# 9900   23336
# 10000   23599
# 10100   23811
# 10200   24066
# 10300   24330
# 10400   24542
# 10500   24736
# 10600   24974
# 10700   25284
# 10800   25552
# 10900   25799
# 11000   26082
# 11100   26348
# 11200   26604
# 11300   26845
# 11400   27100
# 11500   27352
# 11600   27567
# 11700   27773
# 11800   28026
# 11900   28269
# 12000   28499
# 12100   28688
# 12200   28934
# 12300   29176
# 12400   29348
# 12500   29539
# 12600   29817
# 12700   30049
# 12800   30428
# 12900   30687
# 13000   30991
# 13100   31258
# 13200   31528
# 13300   31768
# 13400   31979
# 13500   32205
# 13600   32427
# 13700   32699
# 13800   32946
# 13900   33189
# 14000   33409
# 14100   33618
# 14200   33836
# 14300   34097
# 14400   34301
# 14500   34574
# 14600   34925
# 14700   35197
# 14800   35375
# 14900   35590
# 15000   35910
# 15100   36141
# 15200   36370
# 15300   36777
# 15400   37000
# 15500   37306
# 15600   37595
# 15700   37891
# 15800   38214
# 15900   38463
# 16000   38685
# 16100   38906
# 16200   39126
# 16300   39351
# 16400   39547
# 16500   39783
# 16600   40077
# 16700   40342
# 16800   40648
# 16900   40903
# 17000   41129
# 17100   41397
# 17200   41625
# 17300   41842
# 17400   42110
# 17500   42327
# 17600   42538
# 17700   42841
# 17800   43069
# 17900   43324
# 18000   43572

# %%
new_df.head(10)
# Out:
#    level_0  index      budget contentRating     country  critic_ratings duration                        genre  gross language                                      location_page                        name  opening_weekend                  release_dates                url  user_ratings user_ratings_count  year                                   separated_places             coordinates coordinates_cities
# 0        0      0  €1,500,000           NaN  Kazakhstan             NaN  110 min                      [Drama]    NaN  Russian  [Minsk, Belarus , Almaty, Kazakhstan , St. Pet...                Ya ne vernus              NaN      [ 1 March 2014 (Russia) ]  /title/tt2637844/           6.9                320  2014  [minsk, belarus, almaty, kazakhstan, st. peter...        (53.9, 27.56667)              minsk
# 1        0      0  €1,500,000           NaN  Kazakhstan             NaN  110 min                      [Drama]    NaN  Russian  [Minsk, Belarus , Almaty, Kazakhstan , St. Pet...                Ya ne vernus              NaN      [ 1 March 2014 (Russia) ]  /title/tt2637844/           6.9                320  2014  [minsk, belarus, almaty, kazakhstan, st. peter...    (43.25654, 76.92848)             almaty
# 2        2      3         NaN           NaN         USA             NaN   85 min  [Horror, Mystery, Thriller]    NaN  English                             [Silt, Colorado, USA ]                     Find Me              NaN     [ 1 September 2014 (USA) ]  /title/tt3027188/           4.5                649  2014                              [silt, colorado, usa]  (39.54859, -107.65617)               silt
# 3        3      4         NaN           NaN     Ireland             NaN   88 min      [Comedy, Drama, Family]    NaN  English  [Dublin, County Dublin, Ireland , County Wickl...                        Gold              NaN  [ 10 October 2014 (Ireland) ]  /title/tt3134422/           6.1                406  2014  [dublin, county dublin, ireland, county wicklo...    (53.33306, -6.24889)             dublin
# 4        7     10         NaN           Not         USA             NaN   85 min   [Action, Sci-Fi, Thriller]    NaN  English  [Los Angeles, California, USA , Long Beach, Ca...  Mega Shark vs. Mecha Shark              NaN      [ 28 January 2014 (USA) ]  /title/tt3152098/           2.6              1,988  2014  [los angeles, california, usa, long beach, cal...  (34.05223, -118.24368)        los angeles
# 5        7     10         NaN           Not         USA             NaN   85 min   [Action, Sci-Fi, Thriller]    NaN  English  [Los Angeles, California, USA , Long Beach, Ca...  Mega Shark vs. Mecha Shark              NaN      [ 28 January 2014 (USA) ]  /title/tt3152098/           2.6              1,988  2014  [los angeles, california, usa, long beach, cal...   (41.73893, -86.85697)         long beach
# 6        8     11         NaN           NaN      Poland             NaN  117 min             [Drama, Romance]    NaN   Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                  Obce cialo              NaN   [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014  [ancona, marche, italy, warsaw, mazowieckie, p...     (43.5942, 13.50337)             ancona
# 7        8     11         NaN           NaN      Poland             NaN  117 min             [Drama, Romance]    NaN   Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                  Obce cialo              NaN   [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014  [ancona, marche, italy, warsaw, mazowieckie, p...    (41.2381, -85.85305)             warsaw
# 8        8     11         NaN           NaN      Poland             NaN  117 min             [Drama, Romance]    NaN   Polish  [Ancona, Marche, Italy , Warsaw, Mazowieckie, ...                  Obce cialo              NaN   [ 5 December 2014 (Poland) ]  /title/tt3997248/           4.6                156  2014  [ancona, marche, italy, warsaw, mazowieckie, p...    (55.75222, 37.61556)             moscow

# %% [markdown]
# Data Cleaning part

# %%
#taking cities with largest population to resolve conflict

dfcoordinates = []
for entry in df_boolean['separated_places']:
    print entry
    row_coordinates = [coordinatesdict[x] for x in entry if x in coordinatesdict]
    print row_coordinates
    print
# Out:
# ['minsk', 'belarus', 'almaty', 'kazakhstan', 'st. petersburg', 'russia']
# [('53.9', '27.56667'), ('43.25654', '76.92848')]
#
# ['silt', 'colorado', 'usa']
# [('39.54859', '-107.65617')]
#
# ['dublin', 'county dublin', 'ireland', 'county wicklow', 'ireland']
# [('53.33306', '-6.24889')]
#
# ['los angeles', 'california', 'usa', 'long beach', 'california', 'usa']
# [('34.05223', '-118.24368'), ('41.73893', '-86.85697')]
#
# ['ancona', 'marche', 'italy', 'warsaw', 'mazowieckie', 'poland', 'moscow', 'russia']
# [('43.5942', '13.50337'), ('41.2381', '-85.85305'), ('55.75222', '37.61556')]
#
# ['angelus oaks', 'california', 'usa', 'california', 'usa', 'usa']
# []
#
# ['akademie der k\xc3\xbcnste', 'berlin', 'germany', 'haus der kulturen der welt', 'berlin', 'germany']
# [('44.46867', '-71.18508'), ('44.46867', '-71.18508')]
#
# ['falkenberg', 'hallands l\xc3\xa4n', 'sweden', 'uddevalla', 'v\xc3\xa4stra g\xc3\xb6talands l\xc3\xa4n', 'sweden', 'gothenburg', 'v\xc3\xa4stra g\xc3\xb6talands l\xc3\xa4n', 'sweden', 'halmstad', 'hallands l\xc3\xa4n', 'sweden']
# [('52.568', '13.54597'), ('58.34784', '11.9424'), ('40.92945', '-100.16068'), ('56.67446', '12.85676')]
#
# ['new york', 'usa', 'paulsboro', 'new jersey', 'usa', 'philadelphia', 'pennsylvania', 'usa']
# [('39.83039', '-75.24046'), ('44.1545', '-75.70882')]
#
# ['wales', 'uk']
# [('42.06954', '-72.2223')]
#
# ['denver', 'colorado', 'usa']
# [('42.67137', '-92.3374')]
#
# ['santiago', 'chile']
# [('17.2939', '120.4449')]
#
# ['lisbon', 'portugal']
# [('41.92112', '-91.38545')]
#
# ['marquam', 'oregon', 'usa', 'silverton', 'oregon', 'usa', 'salem', 'oregon', 'usa', 'corvallis', 'oregon', 'usa']
# [('39.19284', '-84.4005'), ('-7.1825', '108.8059'), ('44.56457', '-123.26204')]
#
# ['china']
# []
#
# ['cologne', 'north rhine-westphalia', 'germany', 'india', 'z\xc3\xbcrich', 'kanton z\xc3\xbcrich', 'switzerland']
# [('44.77163', '-93.78135'), ('47.36667', '8.55')]
#
# ['chicago', 'illinois', 'usa']
# [('41.85003', '-87.65005')]
#
# ['frankfurt am main', 'hessen', 'germany']
# [('50.11552', '8.68417')]
#
# ['hyderabad', 'telangana', 'india']
# [('25.39242', '68.37366')]
#
# ['springfield', 'tennessee', 'usa', 'destin', 'florida', 'usa', 'destin', 'florida', 'usa', 'springfield', 'tennessee', 'usa', 'tennessee', 'usa', 'florida', 'usa', 'usa']
# [('43.49507', '-72.03342'), ('30.39353', '-86.49578'), ('30.39353', '-86.49578'), ('43.49507', '-72.03342')]
#
# ['moriarty', 'new mexico', 'usa', 'estancia', 'new mexico', 'usa', 'edgewood', 'new mexico', 'usa']
# [('34.99005', '-106.04919'), ('11.4551', '123.152'), ('32.69818', '-95.88524')]
#
# ['mohonk preserve', 'new paltz', 'new york', 'usa', 'ashokan center', 'olivebridge', 'new york', 'usa']
# [('41.74759', '-74.08681')]
#
# ['hokkaido', 'japan']
# []
#
# ['kolkata', 'west bengal', 'india', 'turkey']
# [('22.56263', '88.36304')]
#
# ['italy']
# []
#
# ['usa']
# []
#
# ['b\xc3\xa5stad', 'sk\xc3\xa5ne l\xc3\xa4n', 'sweden', 'malm\xc3\xb6', 'sk\xc3\xa5ne l\xc3\xa4n', 'sweden']
# [('56.42689', '12.85339'), ('55.60587', '13.00073')]
#
# ['los angeles', 'california', 'usa', "chip's restaurant 11908 hawthorne blvd", 'hawthorne', 'california', 'usa', '1305 ingraham st.', 'los angeles', 'california', 'usa', 'silver lake medical center - 1711 w. temple st', 'los angeles', 'california', 'usa', '929 e 2nd st', 'los angeles', 'california', 'usa']
# [('34.05223', '-118.24368'), ('29.59191', '-82.08732'), ('34.05223', '-118.24368'), ('34.05223', '-118.24368'), ('34.05223', '-118.24368')]
#
# ['france']
# []
#
# ['tampa', 'florida', 'usa', 'lakeland', 'florida', 'usa', 'sarasota', 'florida', 'usa']
# [('27.94752', '-82.45843'), ('35.23064', '-89.74036'), ('27.33643', '-82.53065')]
#
# ['new orleans', 'louisiana', 'usa']
# [('29.95465', '-90.07507')]
#
# ['linnunlaulu', 'helsinki', 'finland']
# [('60.16952', '24.93545')]
#
# ['clear lake', 'texas', 'usa', 'houston', 'texas', 'usa', 'pearland', 'texas', 'usa']
# [('48.46427', '-122.23404'), ('40.24646', '-80.21145'), ('29.56357', '-95.28605')]
#
# ['goshen', 'indiana', 'usa', 'elkhart', 'indiana', 'usa', 'st. joseph', 'michigan', 'usa', 'middlebury', 'indiana', 'usa', 'bristol', 'indiana', 'usa']
# [('36.10119', '-93.99131'), ('31.62517', '-95.5794'), ('39.26421', '-87.1189'), ('41.72144', '-85.81749')]
#
# ['denver', 'colorado', 'usa']
# [('42.67137', '-92.3374')]
#
# ['salvador', 'bahia', 'brazil']
# [('-12.97111', '-38.51083')]
#
# ['vancouver', 'british columbia', 'canada']
# [('45.63873', '-122.66149')]
#
# ['hattiesburg', 'mississippi', 'usa', 'biloxi', 'mississippi', 'usa']
# [('31.32712', '-89.29034'), ('30.39603', '-88.88531')]
#
# ['whitewater', 'california', 'usa', 'moonlight rollerway', 'glendale', 'california', 'usa']
# [('42.83362', '-88.73233'), ('43.13529', '-87.93564')]
#
# ['skansen', 'stockholm', 'stockholms l\xc3\xa4n', 'sweden', 'faringe station', 'uppsala-lenna railway', 'uppsala', 'sweden', '\xc3\x85rsta slott', 'haninge', 'sweden']
# [('59.33258', '18.0649'), ('59.85882', '17.63889'), ('59.16775', '18.14478')]
#
# ['seaville', 'new jersey', 'usa', 'new york city', 'new york', 'usa', 'new canaan', 'connecticut', 'usa', 'asbury park', 'new jersey', 'usa', 'long branch', 'new jersey', 'usa', 'highland lakes', 'new jersey', 'usa']
# [('40.71427', '-74.00597'), ('41.14676', '-73.49484'), ('40.22039', '-74.01208'), ('40.30428', '-73.99236')]
#
# ['chennai', 'tamil nadu', 'india']
# [('13.08784', '80.27847')]
#
# ['rome', 'lazio', 'italy']
# [('44.58506', '-69.86922')]
#
# ['preston', 'lancashire', 'england', 'uk', 'blackpool', 'lancashire', 'uk']
# [('53.75663', '-0.19775'), ('34.54426', '-91.96903'), ('53.81667', '-3.05')]
#
# ['las palmas de gran canaria', 'gran canaria', 'canary islands', 'spain', 'madrid', 'spain']
# [('28.09973', '-15.41343'), ('41.87665', '-93.82328')]
#
# ['bratislava', 'slovakia', 'slovakia', 'slovakia']
# [('48.14816', '17.10674')]
#
# ['mexico']
# []
#
# ['naples', 'campania', 'italy']
# [('42.61535', '-77.40249')]
#
# ['victoria', 'british columbia', 'canada']
# [('15.5775', '120.6822')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['oslo', 'norway', 'gr\xc3\xb8nland', 'oslo', 'norway', 'vika', 'oslo', 'norway']
# [('59.91273', '10.74609'), ('59.91273', '10.74609'), ('59.91273', '10.74609')]
#
# ['vilnius', 'vilnius county', 'lithuania', 'rovaniemi', 'finland']
# [('54.68916', '25.2798'), ('66.5', '25.71667')]
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['winchester', 'virginia', 'usa']
# [('38.94174', '-83.65075')]
#
# ['bulgaria', 'santorini', 'greece']
# []
#
# ['morocco']
# []
#
# ['brooklyn', 'new york city', 'new york', 'usa', 'manhattan', 'new york city', 'new york', 'usa']
# [('41.43977', '-81.73541'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597')]
#
# ['san jose', 'california', 'usa', 'los gatos', 'california', 'usa', 'lake tahoe', 'california', 'usa', 'seaside', 'california', 'usa']
# [('13.8784', '121.1045'), ('37.22661', '-121.97468'), ('30.32103', '-86.14161')]
#
# ['slaskie', 'poland', 'szpital wolski', 'kasprzaka', 'wola', 'warsaw', 'mazowieckie', 'poland', 'warsaw', 'mazowieckie', 'poland', 'warminsko-mazurskie', 'poland']
# [('52.2401', '20.98869'), ('41.2381', '-85.85305'), ('41.2381', '-85.85305')]
#
# ['black forest', 'baden-w\xc3\xbcrttemberg', 'germany', 'mecklenburg-western pomerania', 'germany', 'north sea', 'germany']
# [('39.01305', '-104.70081'), ('40.93288', '-72.41425')]
#
# ['enfield', 'london', 'england', 'uk']
# [('43.64063', '-72.14398'), ('35.32897', '-93.25296'), ('34.54426', '-91.96903')]
#
# ['rockaway beach', 'queens', 'new york city', 'new york', 'usa', 'bethesda terrace', 'central park', 'manhattan', 'new york city', 'new york', 'usa', 'paterson', 'new jersey', 'usa', 'cecille b. demille gatehouse', 'wayne', 'new jersey', 'usa', 'garrett mountain reservation', 'west paterson', 'new jersey', 'usa', 'jackson heights', 'queens', 'new york city', 'new york', 'usa', 'lambert castle - 3 valley road', 'paterson', 'new jersey', 'usa', 'wayne', 'new jersey', 'usa']
# [('45.61344', '-123.94291'), ('40.71427', '-74.00597'), ('46.97343', '-123.69239'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('40.91677', '-74.17181'), ('44.34868', '-70.06616'), ('40.71427', '-74.00597'), ('40.91677', '-74.17181'), ('44.34868', '-70.06616')]
#
# ['loyola marymount university - 1 lmu drive', 'westchester', 'los angeles', 'california', 'usa']
# [('41.85059', '-87.882'), ('34.05223', '-118.24368')]
#
# ['mumbai', 'india', 'bangkok', 'thailand']
# [('19.07283', '72.88261'), ('13.75398', '100.50144')]
#
# ['malverne', 'long island', 'new york', 'usa', 'rockville centre', 'long island', 'new york', 'usa', 'merrick', 'new york', 'usa', 'lynbrook', 'long island', 'new york', 'usa', 'valley stream', 'long island', 'new york', 'usa', 'long island', 'new york', 'usa', 'new york', 'usa', 'usa', 'argyle park', 'babylon', 'new york', 'usa', 'islip', 'new york', 'usa', 'sip this coffee shop', 'valley stream', 'new york', 'usa']
# [('40.67899', '-73.67402'), ('40.65871', '-73.64124'), ('40.66288', '-73.55152'), ('40.65483', '-73.6718'), ('40.66427', '-73.70846'), ('40.69566', '-73.32568'), ('40.72982', '-73.21039'), ('40.66427', '-73.70846')]
#
# ['jackson', 'wyoming', 'usa']
# [('37.38227', '-89.66621')]
#
# ['mission hills', 'los angeles', 'california', 'usa']
# [('39.01778', '-94.6169'), ('34.05223', '-118.24368')]
#
# ['charleroi', 'pennsylvania', 'usa', 'parkersburg', 'west virginia', 'usa', 'monongahela', 'pennsylvania', 'usa', 'washington', 'pennsylvania', 'usa']
# [('50.41136', '4.44448'), ('42.57748', '-92.78686'), ('40.20313', '-79.92616')]
#
# ['youngsville', 'north carolina', 'usa']
# [('36.02487', '-78.47444')]
#
# ['isle of man', 'northern ireland', 'uk']
# []
#
# ['derbyshire', 'england', 'uk', 'derby', 'derbyshire', 'england', 'uk']
# [('34.54426', '-91.96903'), ('41.32065', '-73.089'), ('34.54426', '-91.96903')]
#
# ['albuquerque', 'new mexico', 'usa', 'tijeras', 'new mexico', 'usa', 'new mexico', 'usa']
# [('35.08449', '-106.65114'), ('8.47514', '-82.56058')]
#
# ['ashridge park', 'little gaddesden', 'hertfordshire', 'england', 'uk', 'petworth house', 'petworth', 'west sussex', 'england', 'uk', 'pinewood studios', 'iver heath', 'buckinghamshire', 'england', 'uk']
# [('34.54426', '-91.96903'), ('50.98669', '-0.61'), ('34.54426', '-91.96903'), ('34.54426', '-91.96903')]
#
# ['lake los angeles', 'california', 'usa', 'victorville', 'california', 'usa', 'antelope valley', 'california', 'usa', 'little rock', 'california', 'usa']
# [('34.61249', '-117.82812'), ('34.53611', '-117.29116'), ('47.86801', '-95.11055')]
#
# ['kuala lumpur', 'malaysia', 'taipei', 'taiwan']
# [('3.1412', '101.68653'), ('25.04776', '121.53185')]
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['france', 'luxembourg']
# []
#
# ['evansville', 'indiana', 'usa', 'vanderburgh county', 'indiana', 'usa', 'posey county', 'indiana', 'usa', 'warrick county', 'indiana', 'usa']
# [('37.97476', '-87.55585')]
#
# ['parry sound', 'ontario', 'canada']
# [('45.34732', '-80.03527'), ('44.02655', '-116.96294')]
#
# ['annapoorna studios', 'hyderabad', 'telangana', 'india', 'ramanaidu studios', 'hyderabad', 'telangana', 'india', 'd. rama naidu studios', 'hyderabad', 'telangana', 'india']
# [('25.39242', '68.37366'), ('25.39242', '68.37366'), ('25.39242', '68.37366')]
#
# ['tahoe city', 'california', 'usa']
# []
#
# ['west midlands', 'england', 'uk', 'derbyshire', 'england', 'uk', 'france']
# [('34.54426', '-91.96903'), ('34.54426', '-91.96903')]
#
# ['albuquerque', 'new mexico', 'usa']
# [('35.08449', '-106.65114')]
#
# ['bucharest', 'romania']
# [('44.43225', '26.10626')]
#
# ['cabo espichel', 'sesimbra', 'set\xc3\xbabal', 'portugal', 'c\xc3\xa1ceres', 'extremadura', 'spain', 'badajoz', 'extremadura', 'spain', 'granadilla', 'c\xc3\xa1ceres', 'extremadura', 'spain']
# [('38.44451', '-9.10149'), ('38.5244', '-8.8882'), ('7.58078', '-75.34842'), ('38.87789', '-6.97061'), ('9.93491', '-84.01688'), ('7.58078', '-75.34842')]
#
# ['vienna', 'austria', 'lower austria', 'austria', 'salzburg', 'austria']
# [('39.32702', '-81.54846'), ('47.79941', '13.04399')]
#
# ['virginia', 'usa']
# []
#
# ['hokkaido', 'japan', 'tokyo', 'japan']
# [('35.6895', '139.69171')]
#
# ['los angeles', 'california', 'usa', 'san diego', 'california', 'usa']
# [('34.05223', '-118.24368'), ('10.25982', '-67.9533')]
#
# ['j\xc3\xa4mtlands l\xc3\xa4n', 'sweden', '\xc3\x96stersund', 'j\xc3\xa4mtlands l\xc3\xa4n', 'sweden']
# [('63.1792', '14.63566')]
#
# ['rochester', 'new york', 'usa']
# [('55.2752', '-2.2649')]
#
# ['bucharest', 'romania', 'romania', 'carol park mausoleum', 'carol park', 'bucharest', 'romania', 'carol park', 'bucharest', 'romania', 'lipscani', 'bucharest', 'romania']
# [('44.43225', '26.10626'), ('44.43225', '26.10626'), ('44.43225', '26.10626'), ('44.43225', '26.10626')]
#
# ['san benedetto del tronto', 'ascoli piceno', 'marche', 'italy', 'pescara', 'abruzzo', 'italy', 'ascoli piceno', 'marche', 'italy', 'roma', 'lazio', 'italy']
# [('42.9568', '13.87676'), ('42.85351', '13.57395'), ('42.4584', '14.20283'), ('42.85351', '13.57395'), ('47.83333', '26.6')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['barbados']
# []
#
# ['usa', 'france']
# []
#
# ['amsterdam', 'noord-holland', 'netherlands', 'pittsburgh', 'pennsylvania', 'usa', 'pittsburgh', 'pennsylvania', 'usa', 'netherlands', 'usa']
# [('42.93869', '-74.18819'), ('40.44062', '-79.99589'), ('40.44062', '-79.99589')]
#
# ['lawrence', 'massachusetts', 'usa', 'north andover', 'massachusetts', 'usa', 'providence', 'rhode island', 'usa', 'boston', 'massachusetts', 'usa', 'franklin', 'maine', 'usa']
# [('39.83865', '-86.02526'), ('42.6987', '-71.13506'), ('41.82399', '-71.41283'), ('30.79186', '-83.78989'), ('40.09612', '-98.95258')]
#
# ['latvia']
# []
#
# ['warsaw', 'mazowieckie', 'poland']
# [('41.2381', '-85.85305')]
#
# ['studios de paris', 'la cit\xc3\xa9 du cin\xc3\xa9ma', 'saint-denis', 'seine-saint-denis', 'france']
# [('-20.88231', '55.4504')]
#
# ['connecticut', 'usa']
# []
#
# ['queensland', 'australia', 'surfers paradise', 'queensland', 'australia', 'australia']
# [('-28.00274', '153.42999')]
#
# ['iowa city', 'iowa', 'usa', 'burlington', 'iowa', 'usa']
# [('41.66113', '-91.53017'), ('42.67807', '-88.2762')]
#
# ['toronto', 'ontario', 'canada', 'niagara', 'canada', 'chandigarh', 'india']
# [('43.70011', '-79.4163'), ('44.02655', '-116.96294'), ('45.77135', '-87.99485'), ('30.73629', '76.7884')]
#
# ['oakland', 'california', 'usa', 'san francisco', 'california', 'usa', 'fremont', 'california', 'usa', 'alameda', 'california', 'usa', 'hayward', 'california', 'usa']
# [('34.1001', '-96.79389'), ('-20.71667', '-64.7'), ('35.54544', '-77.97471'), ('37.2087', '-4.6586'), ('37.66882', '-122.0808')]
#
# ['lliria', 'comunidad valenciana', 'spain']
# []
#
# ['jakarta', 'indonesia']
# [('-6.21462', '106.84513')]
#
# ['orlando', 'florida', 'usa', 'philadelphia', 'pennsylvania', 'usa']
# [('28.53834', '-81.37924'), ('44.1545', '-75.70882')]
#
# ['algarve', 'portugal', 'ar\xc3\xa3o', 'algarve', 'portugal', 'queren\xc3\xa7a', 'algarve', 'portugal', 'estombar', 'algarve', 'portugal', 'vila vita parc', 'arma\xc3\xa7\xc3\xa3o de pera', 'algarve', 'portugal', 'zoomarine', 'guia', 'algarve', 'portugal']
# [('28.13974', '-15.63294')]
#
# ['gisborne', 'new zealand', 'oamaru', 'new zealand']
# [('-38.65333', '178.00417')]
#
# ['jackson county', 'indiana', 'usa', 'plymouth county courthouse', 'plymouth', 'massachusetts', 'usa', 'shelburne falls', 'massachusetts', 'usa', 'dedham', 'massachusetts', 'usa', 'attleboro', 'massachusetts', 'usa', 'worcester', 'massachusetts', 'usa', 'boston', 'massachusetts', 'usa', 'milton', 'massachusetts', 'usa', 'belmont', 'massachusetts', 'usa', 'stage 29', 'warner brothers burbank studios - 4000 warner boulevard', 'burbank', 'california', 'usa']
# [('16.70555', '-62.21292'), ('42.60425', '-72.73926'), ('44.69174', '-68.66198'), ('41.94454', '-71.28561'), ('52.18935', '-2.22001'), ('30.79186', '-83.78989'), ('41.65982', '-73.95708'), ('35.24292', '-81.0373'), ('34.18084', '-118.30897')]
#
# ['kashmir']
# []
#
# ['los angeles', 'california', 'usa', 'hilton head', 'south carolina', 'usa', 'paramount ranch - 2813 cornell road', 'agoura', 'california', 'usa']
# [('34.05223', '-118.24368'), ('34.14306', '-118.73787')]
#
# ['sosnowiec', 'slaskie', 'poland']
# [('50.28682', '19.10385')]
#
# ['miami', 'florida', 'usa', 'nassau', 'paradise island', 'bahamas']
# [('36.87451', '-94.87746'), ('42.51591', '-73.61012')]
#
# ['west bengal', 'india', 'dooars', 'west bengal', 'india']
# []
#
# ['fort langley', 'langley township', 'british columbia', 'canada', 'mission', 'british columbia', 'canada', 'vancouver', 'british columbia', 'canada', 'everett', 'washington', 'usa', 'surrey', 'british columbia', 'canada']
# [('45.67041', '-118.68359'), ('45.63873', '-122.66149'), ('47.97898', '-122.20208'), ('49.10635', '-122.82509')]
#
# ['manila', 'metro manila', 'philippines', 'manila', 'philippines', 'philippines']
# [('14.6042', '120.9822'), ('14.6042', '120.9822')]
#
# ['kharkiv', 'ukraine', 'lviv', 'ukraine', 'kiev', 'ukraine']
# [('49.98081', '36.25272'), ('50.45466', '30.5238')]
#
# ['mexico city', 'distrito federal', 'mexico']
# [('19.42847', '-99.12766')]
#
# ['romania']
# []
#
# ['hakodate', 'hokkaido', 'japan']
# [('41.77583', '140.73667')]
#
# ['adelaide', 'south australia', 'australia', 'adelaide studios', '226 fullarton road', 'glenside', 'australia', 'australia']
# [('-32.70747', '26.29564'), ('40.10233', '-75.15212')]
#
# ['salaj', 'romania', 'cluj-napoca', 'romania', 'romania', 'transylvania', 'romania']
# [('46.76667', '23.6')]
#
# ['muldersdrift', 'south africa', 'pretoria', 'gauteng', 'south africa', 'ponte city tower - hillbrow', 'johannesburg', 'south africa', 'hillbrow', 'johannesburg', 'south africa', 'johannesburg', 'south africa', 'south africa']
# [('-25.74486', '28.18783'), ('-26.20227', '28.04363'), ('-26.20227', '28.04363'), ('-26.20227', '28.04363')]
#
# ['richland', 'washington', 'usa', 'kennewick', 'washington', 'usa', 'benton city', 'washington', 'usa']
# [('32.08793', '-84.66742'), ('46.21125', '-119.13723'), ('46.26319', '-119.4878')]
#
# ['con sazon', 'glendale', 'california', 'usa', 'the house of gods', 'downtown los angeles', 'california', 'usa']
# [('43.13529', '-87.93564')]
#
# ['stockholm', 'sweden', 'stj\xc3\xa4rnhov', 's\xc3\xb6rmland', 'sweden', 'globen', 'stockholm', 'stockholms l\xc3\xa4n', 'sweden']
# [('59.33258', '18.0649'), ('59.33258', '18.0649')]
#
# ['belgium', 'japan']
# []
#
# ['manhattan', 'new york city', 'new york', 'usa']
# [('40.78343', '-73.96625'), ('40.71427', '-74.00597')]
#
# ['futtsu', 'chiba', 'japan']
# [('35.30528', '139.81861'), ('33.64657', '104.78224')]
#
# ['lithuania', 'india']
# []
#
# ['united arab emirates', 'manchester', 'greater manchester', 'england', 'uk', 'london', 'england', 'uk', 'miami', 'florida', 'usa']
# [('35.48174', '-86.0886'), ('34.54426', '-91.96903'), ('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('36.87451', '-94.87746')]
#
# ['mandarmani', 'west bengal', 'india']
# []
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['oklahoma city', 'oklahoma', 'usa', 'guthrie', 'oklahoma', 'usa', 'oklahoma', 'usa']
# [('35.46756', '-97.51643'), ('35.87894', '-97.42532')]
#
# ['brisbane', 'queensland', 'australia']
# [('-27.46794', '153.02809')]
#
# ['los angeles', 'california', 'usa', 'redondo beach', 'california', 'usa', 'palos verdes estates', 'california', 'usa', 'glendale', 'california', 'usa', 'monterey park', 'california', 'usa', 'mumbai', 'maharashtra', 'india']
# [('34.05223', '-118.24368'), ('33.84918', '-118.38841'), ('33.80105', '-118.39245'), ('43.13529', '-87.93564'), ('34.75898', '-106.64085'), ('19.07283', '72.88261')]
#
# ['nagasaki', 'japan', 'toyama', 'japan']
# [('32.75', '129.88333'), ('36.7', '137.21667')]
#
# ['bordertown', 'maple ridge', 'british columbia', 'canada', 'virtue studio ranch', 'mission', 'british columbia', 'canada']
# [('-36.30768', '140.77167'), ('49.21939', '-122.60193'), ('45.67041', '-118.68359')]
#
# ['london', 'england', 'uk', 'longcross studios', 'chobham lane', 'longcross', 'surrey', 'england', 'uk']
# [('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('49.10635', '-122.82509'), ('34.54426', '-91.96903')]
#
# ['seville', 'seville', 'andaluc\xc3\xada', 'spain', 'santa cruz de tenerife', 'tenerife', 'canary islands', 'spain', 'adeje', 'tenerife', 'santa cruz de tenerife', 'canary islands', 'spain', 'arico', 'tenerife', 'santa cruz de tenerife', 'canary islands', 'spain', 'g\xc3\xbcimar', 'tenerife', 'santa cruz de tenerife', 'canary islands', 'spain', 'san crist\xc3\xb3bal de la laguna', 'tenerife', 'santa cruz de tenerife', 'canary islands', 'spain', 'alcal\xc3\xa1 de guadaira', 'sevilla', 'andaluc\xc3\xada', 'spain', 'madrid', 'madrid', 'spain', 'tangier', 'morocco', 'chefchaouen', 'morocco', 'fez', 'f\xc3\xa8s-boulemane', 'morocco']
# [('41.01006', '-81.86236'), ('41.01006', '-81.86236'), ('4.17061', '-76.16641'), ('28.46824', '-16.25462'), ('28.12271', '-16.726'), ('28.46824', '-16.25462'), ('28.46824', '-16.25462'), ('28.31122', '-16.41276'), ('28.46824', '-16.25462'), ('28.46824', '-16.25462'), ('37.33791', '-5.83951'), ('9.70383', '124.04829'), ('4.17061', '-76.16641'), ('41.87665', '-93.82328'), ('41.87665', '-93.82328'), ('35.76727', '-5.79975')]
#
# ['girona', 'girona', 'catalonia', 'spain', 'barcelona', 'catalonia', 'spain', 'sant feliu de gu\xc3\xadxols', 'girona', 'catalonia', 'spain', 'madrid', 'spain']
# [('41.98311', '2.82493'), ('41.98311', '2.82493'), ('41.38879', '2.15899'), ('41.78333', '3.03333'), ('41.98311', '2.82493'), ('41.87665', '-93.82328')]
#
# ['li\xc3\xa8ge', 'wallonia', 'belgium', 'brasschaat', 'antwerp', 'flanders', 'belgium', 'antwerp', 'flanders', 'belgium']
# [('50.63373', '5.56749'), ('51.2912', '4.49182'), ('41.18144', '-84.74051'), ('40.90343', '-72.61759'), ('41.18144', '-84.74051'), ('40.90343', '-72.61759')]
#
# ['veurne', 'belgium']
# [('51.07316', '2.66803')]
#
# ['chiang mai', 'thailand']
# [('18.79038', '98.98468')]
#
# ['connecticut', 'usa']
# []
#
# ['bucharest', 'romania', 'romania', 'bulgaria', 'varna', 'bulgaria', 'new boyana film studios', 'sofia', 'bulgaria', 'sofia', 'bulgaria', 'bebresh viaduct', 'vitinya pass', 'bulgaria', 'lipscani', 'bucharest', 'romania', 'university square', 'bucharest', 'romania', 'arcul de triumf', 'bucharest', 'romania', 'sofia airport', 'sofia', 'bulgaria', 'military academy hospital', 'sofia', 'bulgaria', 'vertigo tower', 'sofia', 'bulgaria']
# [('44.43225', '26.10626'), ('44.67914', '19.6515'), ('42.69751', '23.32415'), ('42.69751', '23.32415'), ('44.43225', '26.10626'), ('44.43225', '26.10626'), ('44.43225', '26.10626'), ('42.69751', '23.32415'), ('42.69751', '23.32415'), ('42.69751', '23.32415')]
#
# ['sheffield', 'south yorkshire', 'england', 'uk', 'taiwan', 'cambridge', 'cambridgeshire', 'england', 'uk']
# [('-41.39947', '146.33897'), ('34.54426', '-91.96903'), ('42.3751', '-71.10561'), ('34.54426', '-91.96903')]
#
# ['riverside', 'california', 'usa']
# [('40.95536', '-76.62885')]
#
# ['chicago', 'illinois', 'usa']
# [('41.85003', '-87.65005')]
#
# ['los angeles', 'california', 'usa', 'san francisco', 'california', 'usa']
# [('34.05223', '-118.24368'), ('-20.71667', '-64.7')]
#
# ['vancouver', 'british columbia', 'canada']
# [('45.63873', '-122.66149')]
#
# ['paris', 'france', 'pantin', 'seine-saint-denis', 'france', 'normandie', 'france']
# [('36.302', '-88.32671'), ('48.89437', '2.40935')]
#
# ['kiyik\xc3\xb6y', 'kirklareli', 'turkey']
# []
#
# ['russia', 'france']
# []
#
# ['liege', 'belgium', 'ethiopia']
# []
#
# ['grindstone', 'pennsylvania', 'usa']
# []
#
# ['vanuatu', 'australia', 'vanuatu', 'australia']
# []
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['san francisco', 'california', 'usa', 'berkeley', 'california', 'usa']
# [('-20.71667', '-64.7'), ('37.87159', '-122.27275')]
#
# ['thane', 'maharashtra', 'india']
# []
#
# ['jardin de batignolles', 'paris 17', 'paris', 'france', 'place charles fillion', 'paris 17', 'paris', 'france', '21 rue brochant', 'paris 17', 'paris', 'france', '42 rue pouchet', 'paris 17', 'paris', 'france', 'porte maillot', 'paris 17', 'paris', 'france', 'th\xc3\xa9\xc3\xa2tre des feuillants - 9 rue condorcet', 'dijon', "c\xc3\xb4te-d'or", 'france', 'rue lemercier', 'paris 17', 'paris', 'france', 'quai de la seine', 'paris', 'france']
# [('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('47.31667', '5.01667'), ('36.302', '-88.32671'), ('36.302', '-88.32671')]
#
# ['southampton', 'long island', 'new york', 'usa']
# [('50.90395', '-1.40428')]
#
# ['albuquerque', 'new mexico', 'usa']
# [('35.08449', '-106.65114')]
#
# ['malta']
# []
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['charlotte', 'north carolina', 'usa', 'belmont', 'north carolina', 'usa']
# [('36.17728', '-87.33973'), ('35.24292', '-81.0373')]
#
# ['manhattan', 'new york city', 'new york', 'usa', 'new york city', 'new york', 'usa', 'southampton', 'long island', 'new york', 'usa']
# [('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597'), ('50.90395', '-1.40428')]
#
# ['maine', 'usa']
# []
#
# ['memphis', 'tennessee', 'usa']
# [('42.89642', '-82.76881')]
#
# ['bucharest', 'romania', 'romania']
# [('44.43225', '26.10626')]
#
# ['south africa', 'johannesburg', 'south africa']
# [('-26.20227', '28.04363')]
#
# ['singapore', 'philipines']
# []
#
# ['new york', 'usa', 'usa']
# []
#
# ['kabala train station', 'viru-kabala', 'l\xc3\xa4\xc3\xa4ne-viru', 'estonia', 'tapa army training center', 'tapa', 'l\xc3\xa4\xc3\xa4ne-viru', 'estonia']
# [('59.26056', '25.95861')]
#
# ['mt. pleasant', 'michigan', 'usa', 'sterling heights', 'michigan', 'usa']
# [('42.58031', '-83.0302')]
#
# ['asunci\xc3\xb3n', 'paraguay', 'northern california', 'california', 'usa']
# [('-25.30066', '-57.63591')]
#
# ['denmark']
# []
#
# ['shanghai', 'china']
# [('31.22222', '121.45806')]
#
# ['paris', 'france', 'aubervilliers', 'seine-saint-denis', 'france', 'mennecy', 'essonne', 'france']
# [('36.302', '-88.32671'), ('48.91667', '2.38333'), ('48.56903', '2.44384')]
#
# ['mexico city', 'distrito federal', 'mexico']
# [('19.42847', '-99.12766')]
#
# ['cit\xc3\xa9 de la noue', 'bagnolet', 'seine-saint-denis', 'france', 'la d\xc3\xa9fense', 'hauts-de-seine', 'france', 'forum des halles', 'paris 1', 'paris', 'france']
# [('48.86667', '2.41667'), ('36.302', '-88.32671')]
#
# ['apulia', 'italy']
# []
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['mississauga', 'ontario', 'canada', 'port credit', 'ontario', 'canada', 'toronto', 'ontario', 'canada', 'sedona', 'arizona', 'usa', 'los angeles', 'california', 'usa']
# [('43.5789', '-79.6583'), ('44.02655', '-116.96294'), ('44.02655', '-116.96294'), ('43.70011', '-79.4163'), ('44.02655', '-116.96294'), ('34.86974', '-111.76099'), ('34.05223', '-118.24368')]
#
# ['tel aviv', 'israel']
# [('32.08088', '34.78057')]
#
# ['bogot\xc3\xa1', 'colombia']
# [('4.60971', '-74.08175')]
#
# ['calgary', 'alberta', 'canada']
# [('51.05011', '-114.08529')]
#
# ['vishakhapatnam', 'andhra pradesh', 'india', 'dubai', 'united arab emirates']
# [('25.0657', '55.17128')]
#
# ['london', 'england', 'uk', 'johannesburg', 'south africa']
# [('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('-26.20227', '28.04363')]
#
# ['covington', 'louisiana', 'usa', 'new orleans', 'louisiana', 'usa', 'ascension parish', 'louisiana', 'madisonville', 'louisiana', 'usa', 'pearl river', 'louisiana', 'usa', 'st. tammany parish', 'louisiana', 'usa']
# [('33.59678', '-83.86018'), ('29.95465', '-90.07507'), ('37.3281', '-87.49889'), ('41.05899', '-74.02181')]
#
# ['seville', 'seville', 'andaluc\xc3\xada', 'spain']
# [('41.01006', '-81.86236'), ('41.01006', '-81.86236'), ('4.17061', '-76.16641')]
#
# ['kolhapur', 'maharashtra', 'india']
# []
#
# ['israel']
# []
#
# ['shenzhen', 'china', 'taishan', 'guangdong', 'china']
# [('29.41591', '121.33971'), ('32.15059', '118.70475')]
#
# ['vienna', 'austria', 'tyrol', 'austria']
# [('39.32702', '-81.54846')]
#
# ['pinewood toronto studios', 'port lands', 'toronto', 'ontario', 'canada', 'toronto', 'ontario', 'canada']
# [('43.70011', '-79.4163'), ('44.02655', '-116.96294'), ('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['kasteel de haar', 'haarzuilens', 'utrecht', 'netherlands']
# [('52.09083', '5.12222')]
#
# ['taipei city', 'taiwan', 'hotel regent', 'taipei', 'taiwan', 'paris', 'france', 'taiwan', 'studios de paris', 'la cit\xc3\xa9 du cin\xc3\xa9ma', 'saint-denis', 'seine-saint-denis', 'france', 'tegel airport', 'tegel', 'berlin', 'germany', 'la sorbonne', 'paris 5', 'paris', 'france', 'rue de rivoli', 'paris 1', 'paris', 'france', 'camargue', 'bouches-du-rh\xc3\xb4ne', 'france', 'gorges du tarn', 'loz\xc3\xa8re', 'france', 'germany', 'paris charles de gaulle airport', 'roissy-en-france', "val-d'oise", 'france', "les falaises d'\xc3\x89tretat", '\xc3\x89tretat', 'seine-maritime', 'france', 'loz\xc3\xa8re', 'france', 'france', 'val-de-gr\xc3\xa2ce - 74 boulevard de port-royal', 'paris 5', 'paris', 'france']
# [('25.04776', '121.53185'), ('36.302', '-88.32671'), ('-20.88231', '55.4504'), ('52.57601', '13.29389'), ('44.46867', '-71.18508'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('49.00443', '2.51703'), ('49.70669', '0.20523'), ('36.302', '-88.32671')]
#
# ['moscow', 'russia', 'los angeles', 'california', 'usa']
# [('55.75222', '37.61556'), ('34.05223', '-118.24368')]
#
# ['krak\xc3\xb3w', 'malopolskie', 'poland', 'brzesko', 'malopolskie', 'poland', 'nowy sacz', 'malopolskie', 'poland', 'mala', 'krak\xc3\xb3w', 'malopolskie', 'poland', 'felicjanek', 'krak\xc3\xb3w', 'malopolskie', 'poland']
# [('50.06143', '19.93658'), ('49.96911', '20.60606'), ('29.28262', '108.85044'), ('50.06143', '19.93658'), ('50.06143', '19.93658')]
#
# ['atlantic city', 'new jersey', 'usa', 'boston', 'massachusetts', 'usa', 'lake champlain', 'new york', 'usa', 'ledyard', 'connecticut', 'usa']
# [('39.36428', '-74.42293'), ('30.79186', '-83.78989')]
#
# ['g\xc3\xb6rlitz', 'saxony', 'germany', 'zwinger', 'dresden', 'saxony', 'germany', 'krak\xc3\xb3w', 'malopolskie', 'poland', 'hainewalde', 'saxony', 'germany', 'dresden', 'saxony', 'germany', 'osterstein castle', 'zwickau', 'saxony', 'germany', 'waldenburg', 'saxony', 'germany', 's\xc3\xa4chsische schweiz', 'saxony', 'germany', 'studio babelsberg', 'potsdam', 'brandenburg', 'germany', 'poland', 'germany']
# [('51.15518', '14.98853'), ('40.12146', '-82.01069'), ('50.06143', '19.93658'), ('50.91667', '14.7'), ('40.12146', '-82.01069'), ('50.72724', '12.48839'), ('47.38333', '7.75'), ('52.39886', '13.06566'), ('37.99896', '-86.16941')]
#
# ['toronto', 'ontario', 'canada']
# [('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['brentwood', 'los angeles', 'california', 'usa', 'malibu', 'california', 'usa']
# [('38.94317', '-76.95664'), ('34.05223', '-118.24368'), ('34.00501', '-118.81009')]
#
# ['new york city', 'new york', 'usa', 'hanover', 'new hampshire', 'usa', 'southampton', 'long island', 'new york', 'usa']
# [('40.71427', '-74.00597'), ('40.80454', '-74.36682'), ('50.90395', '-1.40428')]
#
# ['athens', 'greece', 'quebec', 'canada', 'buenos aires', 'federal district', 'argentina', 'london', 'england', 'uk', 'england', 'france', 'italy']
# [('42.08866', '-85.23471'), ('8.41384', '-81.4844'), ('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('34.54426', '-91.96903')]
#
# ['oslo', 'norway', 'cologne', 'north rhine-westphalia', 'germany', 'paris', 'france']
# [('59.91273', '10.74609'), ('44.77163', '-93.78135'), ('36.302', '-88.32671')]
#
# ['buenos aires', 'federal district', 'argentina']
# [('8.41384', '-81.4844')]
#
# ['paris', '\xc3\x8ele-de-france', 'france', 'maisons-laffitte', 'yvelines', 'france', 'saumur', 'maine-et-loire', 'france']
# [('36.302', '-88.32671'), ('48.95264', '2.14521'), ('47.26667', '-0.08333')]
#
# ['niagara falls', 'ontario', 'canada', 'toronto film studios', 'toronto', 'ontario', 'canada']
# [('43.0945', '-79.05671'), ('44.02655', '-116.96294'), ('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['lille', 'nord', 'france', 'gare de lille europe', 'lille', 'nord', 'france']
# [('51.24197', '4.82313'), ('51.24197', '4.82313')]
#
# ['madrid', 'spain', 'albendiego', 'guadalajara', 'castilla-la mancha', 'spain', 'bielsa', 'huesca', 'arag\xc3\xb3n', 'spain']
# [('41.87665', '-93.82328'), ('41.22742', '-3.05171'), ('20.66682', '-103.39182'), ('42.63347', '0.21858'), ('42.13615', '-0.4087')]
#
# ['cleveland', 'ohio', 'usa']
# [('33.744', '-90.72482')]
#
# ['belgrade', 'serbia', 'seoul', 'south korea', 'shimonoseki', 'yamaguchi', 'japan', 'kita kyushu', 'japan']
# [('44.80401', '20.46513'), ('37.566', '126.9784'), ('33.95', '130.95'), ('34.18333', '131.46667')]
#
# ['istanbul', 'turkey', 'bozcaada', '\xc3\x87anakkale', 'turkey']
# [('39.835', '26.06972'), ('40.15552', '26.41271')]
#
# ['national institute of mental health', 'colombo', 'sri lanka']
# [('-25.29167', '-49.22417')]
#
# ['plymouth', 'devon', 'england', 'uk', 'cornwall', 'england', 'uk']
# [('16.70555', '-62.21292'), ('40.04928', '-75.42908'), ('34.54426', '-91.96903'), ('46.22652', '-63.21809'), ('34.54426', '-91.96903')]
#
# ['ocala', 'florida', 'usa', 'apopka', 'florida', 'usa']
# [('29.1872', '-82.14009'), ('28.67617', '-81.51186')]
#
# ['trivandrum', 'kerala', 'india']
# []
#
# ['la perla', 'san juan', 'puerto rico', 'caribe hilton hotel', 'san juan', 'puerto rico']
# [('18.92809', '-97.13365'), ('-21.26667', '-65.3'), ('-21.26667', '-65.3')]
#
# ['seneca', 'south carolina', 'usa']
# [('41.37867', '-79.70394')]
#
# ['denmark']
# []
#
# ['hamburg', 'germany']
# [('40.60445', '-95.65777')]
#
# ['belarus']
# []
#
# ['northridge', 'los angeles', 'california', 'usa', "o'malleys pub", 'seal beach', 'california', 'usa', 'el centro', 'california', 'usa', 'marina del rey', 'california', 'usa', 'san bernardino international airport - 294 s. leland norton way', 'san bernardino', 'california', 'usa', 'blue cloud movie ranch - 20000 blue cloud road', 'santa clarita', 'california', 'usa', 'los angeles', 'california', 'usa', 'oceanside', 'california', 'usa', 'seal beach pier', 'main street', 'seal beach', 'california', 'usa', 'davis bros tire pros - culver city', 'california', 'usa', 'santa clarita', 'california', 'usa', 'los angeles national cemetery - 950 s sepulveda blvd.', 'los angeles', 'california', 'usa', 'highland park', 'los angeles', 'california', 'usa', 'westchester parkway', 'los angeles', 'california', 'usa']
# [('34.22834', '-118.53675'), ('34.05223', '-118.24368'), ('33.74141', '-118.10479'), ('32.792', '-115.56305'), ('33.98029', '-118.45174'), ('-7.18333', '-78.83333'), ('34.39166', '-118.54259'), ('34.05223', '-118.24368'), ('33.19587', '-117.37948'), ('33.74141', '-118.10479'), ('34.39166', '-118.54259'), ('34.05223', '-118.24368'), ('42.40559', '-83.09687'), ('34.05223', '-118.24368'), ('34.05223', '-118.24368')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['evansville', 'indiana', 'usa']
# [('37.97476', '-87.55585')]
#
# ['minas gerais', 'brazil', 'passa quatro', 'minas gerais', 'brazil']
# [('-22.39028', '-44.96667')]
#
# ['south africa']
# []
#
# ['madrid', 'spain', 'buenos aires', 'federal district', 'argentina']
# [('41.87665', '-93.82328'), ('8.41384', '-81.4844')]
#
# ['roma', 'lazio', 'italy']
# [('47.83333', '26.6')]
#
# ['santa clara', 'california', 'usa', 'san jose', 'california', 'usa']
# [('-1.26399', '-77.88739'), ('13.8784', '121.1045')]
#
# ['luxembourg', 'reunion island', 'france']
# []
#
# ['wilmington', 'north carolina', 'usa']
# [('34.22573', '-77.94471')]
#
# ['old delhi', 'central delhi', 'delhi', 'india', 'chandni chowk', 'old delhi', 'central delhi', 'delhi', 'india', 'rajasthan', 'india', 'delhi', 'india', 'bruges', 'west flanders', 'belgium']
# [('37.43216', '-120.77854'), ('37.43216', '-120.77854'), ('37.43216', '-120.77854'), ('44.87981', '-0.61219')]
#
# ['c\xc3\xb3rdoba', 'argentina']
# [('18.8842', '-96.92559')]
#
# ['houston', 'texas', 'usa']
# [('40.24646', '-80.21145')]
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['trivandrum', 'kerala', 'india']
# []
#
# ['poland', 'riga', 'latvia', 'kurdistan', 'iraq', 'portofino', 'genoa', 'liguria', 'italy', 'santa margherita ligure', 'genoa', 'liguria', 'italy']
# [('56.946', '24.10589'), ('44.30349', '9.20942'), ('41.44862', '-97.73061'), ('44.33456', '9.21204'), ('41.44862', '-97.73061')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['brooklyn', 'new york city', 'new york', 'usa', 'new york city', 'new york', 'usa', 'new york', 'usa', 'usa']
# [('41.43977', '-81.73541'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597')]
#
# ['portland', 'ionia county', 'michigan', 'usa', 'michigan', 'usa']
# [('36.58171', '-86.51638')]
#
# ['buenos aires', 'federal district', 'argentina']
# [('8.41384', '-81.4844')]
#
# ['williamsburg', 'brooklyn', 'new york city', 'new york', 'usa']
# [('37.27344', '-76.74148'), ('41.43977', '-81.73541'), ('40.71427', '-74.00597')]
#
# ['mexico city', 'mexico', 'pachuca', 'hidalgo', 'mexico']
# [('19.42847', '-99.12766'), ('26.10035', '-98.26307')]
#
# ['london', 'england', 'uk']
# [('35.32897', '-93.25296'), ('34.54426', '-91.96903')]
#
# ['viedma', 'r\xc3\xado negro', 'argentina', 'denmark']
# [('-40.81345', '-62.99668')]
#
# ['ouarzazate', 'morocco']
# []
#
# ['angoul\xc3\xaame', 'charente', 'france']
# [('45.65', '0.15')]
#
# ['alaska', 'usa']
# []
#
# ['wellington', 'new zealand', 'new zealand']
# [('52.12753', '-2.74899')]
#
# ['biliran', 'philippines']
# [('11.46694', '124.47396')]
#
# ['korso', 'vantaa', 'finland']
# [('60.29414', '25.04099')]
#
# ['ontario', 'canada', 'parry sound', 'ontario', 'canada', 'north bay', 'ontario', 'canada']
# [('44.02655', '-116.96294'), ('45.34732', '-80.03527'), ('44.02655', '-116.96294'), ('46.3168', '-79.46633'), ('44.02655', '-116.96294')]
#
# ['los angeles', 'california', 'usa', 'village market - 11653 moorpark st', 'north hollywood', 'california', 'usa', '52 discovery drive', 'irvine', 'california', 'usa']
# [('34.05223', '-118.24368'), ('34.17223', '-118.37897'), ('33.66946', '-117.82311')]
#
# ['jaffna', 'pooneryn', 'colombo', 'sri lanka']
# [('9.66845', '80.00742'), ('-25.29167', '-49.22417')]
#
# ['missouri', 'usa']
# []
#
# ['athens', 'greece', 'babagarage', 'senegal']
# [('42.08866', '-85.23471')]
#
# ['runaway bay', 'texas', 'usa', 'lake bridgeport', 'texas', 'usa', 'jacksboro', 'texas', 'usa', 'decatur', 'texas', 'usa']
# [('33.16789', '-97.87837'), ('36.33008', '-84.18382'), ('35.51479', '-84.79022')]
#
# ['oahu', 'hawaii', 'usa']
# []
#
# ['west palm beach', 'florida', 'usa', 'miami', 'florida', 'usa']
# [('26.71534', '-80.05337'), ('36.87451', '-94.87746')]
#
# ['munich', 'bavaria', 'germany']
# [('48.13743', '11.57549')]
#
# ['los angeles', 'california', 'usa', 'brixton', 'london', 'england', 'uk', 'los angeles', 'california', 'usa']
# [('34.05223', '-118.24368'), ('51.46593', '-0.10652'), ('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('34.05223', '-118.24368')]
#
# ['london', 'england', 'uk', 'goa', 'india']
# [('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('13.6978', '123.4892')]
#
# ['lake district', 'cumbria', 'england', 'uk']
# [('34.54426', '-91.96903')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['turkey']
# []
#
# ['new york city', 'new york', 'usa', 'brooklyn', 'new york city', 'new york', 'usa', 'manhattan', 'new york', 'usa']
# [('40.71427', '-74.00597'), ('41.43977', '-81.73541'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625')]
#
# ['school #186', 'kiev', 'ukraine', 'sechenova 4 str', 'kiev', 'ukraine', 'ukraine']
# [('50.45466', '30.5238'), ('50.45466', '30.5238')]
#
# ['belfast', 'county antrim', 'northern ireland', 'uk', 'alicante', 'alicante', 'comunidad valenciana', 'spain']
# [('-25.68991', '30.03504'), ('38.34517', '-0.48149'), ('38.34517', '-0.48149')]
#
# ['koninklijk theater carr\xc3\xa9', 'amsterdam', 'noord-holland', 'netherlands']
# [('42.93869', '-74.18819')]
#
# ['parramatta', 'sydney', 'new south wales', 'australia']
# [('46.1351', '-60.1831')]
#
# ['gare sncf', 'place de la gare', 'yvetot', 'seine-maritime', 'france', 'restaurant victor hugo', '1 place melingie', 'veules-les-roses', 'seine-maritime', 'france', 'ferme de la h\xc3\xaatraie', 'th\xc3\xa9rouldeville', 'seine-maritime', 'france', 'supermarch\xc3\xa9 leclerc', 'plateau ouest', 'saint-val\xc3\xa9ry-en-caux', 'seine-maritime', 'france', 'pays de caux', 'haute-normandie', 'france', 'station de m\xc3\xa9tro saint-lazare', 'paris 8', 'paris', 'france', 'rue de rivoli', 'paris 1', 'paris', 'france', 'boutique american apparel', 'paris', 'france', "mus\xc3\xa9e d'orsay", 'paris', 'france', 'station de m\xc3\xa9tro concorde', 'paris 1', 'paris', 'france', 'rue de mondovi', 'paris 1', 'paris', 'france', 'th\xc3\xa9\xc3\xa2tre edouard vii', 'paris 9', 'paris', 'france', 'la grande roue', 'place de la concorde', 'paris 8', 'paris', 'france', 'avenue des champs-\xc3\x89lys\xc3\xa9es', 'paris 8', 'paris', 'france', 'dead sea', 'israel']
# [('49.61744', '0.75814'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671')]
#
# ['east durham', 'new york', 'usa']
# []
#
# ['trondheim', 's\xc3\xb8r tr\xc3\xb8ndelag', 'norway']
# [('63.43049', '10.39506')]
#
# ['huddersfield', 'west yorkshire', 'england', 'uk', 'dewsbury', 'west yorkshire', 'england', 'uk', 'honley', 'west yorkshire', 'england', 'uk', 'north light film studios', 'brookes mill', 'berry brow', 'huddersfield', 'england', 'uk']
# [('53.64904', '-1.78416'), ('34.54426', '-91.96903'), ('53.69076', '-1.62907'), ('34.54426', '-91.96903'), ('34.54426', '-91.96903'), ('53.64904', '-1.78416'), ('34.54426', '-91.96903')]
#
# ['new delhi', 'delhi', 'india']
# [('28.63576', '77.22445'), ('37.43216', '-120.77854')]
#
# ['detroit', 'michigan', 'usa', 'point arena lighthouse', 'california', 'usa', 'macon', 'georgia', 'usa', 'blue ridge', 'georgia', 'usa', 'atlanta', 'georgia', 'usa', 'rome', 'georgia', 'usa', 'phenix city', 'alabama', 'usa', 'phenix city', 'alabama', 'usa', 'columbus', 'georgia', 'usa', 'san francisco', 'california', 'usa', 'moab', 'utah', 'usa', 'alabama', 'usa', 'braselton', 'georgia', 'usa', 'jackson', 'georgia', 'usa', 'mendocino', 'california', 'usa', 'cartersville', 'georgia', 'usa', 'georgia', 'usa', 'bonneville salt flats', 'utah', 'usa', 'manhattan', 'new york', 'usa', 'usa']
# [('42.33143', '-83.04575'), ('39.71282', '-88.99702'), ('34.86397', '-84.32409'), ('40.25948', '-89.23342'), ('44.58506', '-69.86922'), ('32.47098', '-85.00077'), ('32.47098', '-85.00077'), ('31.8276', '-107.64002'), ('-20.71667', '-64.7'), ('38.57332', '-109.54984'), ('34.10927', '-83.76267'), ('37.38227', '-89.66621'), ('34.16533', '-84.80231'), ('40.78343', '-73.96625')]
#
# ['r\xc3\xa9gion nord-pas-de-calais', 'france', 'supermarch\xc3\xa9 d\xc3\xa9saffect\xc3\xa9 netto', 'zone de la seigneurie', 'lamorlaye', 'oise', 'france', "bar-brasserie l'oasis", "march\xc3\xa9 d'int\xc3\xa9r\xc3\xaat national", '1 rue du min', 'lomme', 'nord', 'france', 'lille', 'nord', 'france', 'gravelines', 'nord', 'france', 'roubaix', 'nord', 'france', 'r\xc3\xa9gion parisienne', 'france']
# [('49.16246', '2.44687'), ('50.64358', '2.98715'), ('51.24197', '4.82313'), ('50.98651', '2.12807'), ('50.69421', '3.17456')]
#
# ['vattetot sur mer', 'seine-maritime', 'france', 'belgrade', 'serbia', 'paris', 'france', 'studios de paris', 'la cit\xc3\xa9 du cin\xc3\xa9ma', 'saint-denis', 'seine-saint-denis', 'france', "jardin d'acclimatation", 'bois de boulogne', 'paris 16', 'paris', 'france', "22 rue geoffroy l'asnier", 'paris 4', 'paris', 'france', "15 rue de l'abreuvoir", 'paris 18', 'paris', 'france', 'cit\xc3\xa9 universitaire internationale - 19 boulevard jourdan', 'paris 14', 'paris', 'france', 'petit palais - avenue winston churchill', 'paris 8', 'paris', 'france', "angle rue des barres et rue de l'h\xc3\xb4tel de ville", 'paris 4', 'paris', 'france', 'place dalida', 'paris 18', 'paris', 'france', 'hotel regence - 2 villa de guelma', 'paris 18', 'paris', 'france', 'h\xc3\xb4tel george v', '31 avenue george v', 'paris 8', 'paris', 'france', '76 rue lecourbe', 'paris 15', 'paris', 'france', 'france', 'serbia']
# [('44.80401', '20.46513'), ('36.302', '-88.32671'), ('-20.88231', '55.4504'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671')]
#
# ['columbus', 'wisconsin', 'usa', 'madison', 'wisconsin', 'usa']
# [('31.8276', '-107.64002'), ('38.73589', '-85.37996')]
#
# ['caracas', 'venezuela']
# [('10.48801', '-66.87919')]
#
# ['league city', 'texas', 'usa', 'pasadena', 'texas', 'usa', 'galveston', 'texas', 'usa', 'spring', 'texas', 'usa', 'houston', 'texas', 'usa']
# [('29.50745', '-95.09493'), ('34.14778', '-118.14452'), ('40.57893', '-86.19027'), ('30.07994', '-95.41716'), ('40.24646', '-80.21145')]
#
# ['eastwest studios - 6000 w sunset blvd', 'hollywood', 'california', 'usa', 'torrance', 'california', 'usa', 'bel air', 'los angeles', 'california', 'usa', 'santa clarita', 'california', 'usa', 'point dume', 'malibu', 'california', 'usa', 'griffith observatory', '2800 e observatory rd', 'los angeles', 'california', 'usa', 'ocean way recording', '6050 sunset blvd', 'hollywood', 'california', 'usa', 'los angeles', 'california', 'usa', 'wilshire ebell theatre - 4401 w. 8th st.', 'los angeles', 'california', 'usa', 'westwood boulevard', 'westwood', 'los angeles', 'california', 'usa', 'los angeles sports arena - 3939 s. figueroa street', 'exposition park', 'los angeles', 'california', 'usa', 'hollywood', 'california', 'usa', '2014 stradella road', 'los angeles', 'california', 'usa', 'california', 'usa', 'usa']
# [('26.0112', '-80.14949'), ('33.83585', '-118.34063'), ('39.53594', '-76.34829'), ('34.05223', '-118.24368'), ('34.39166', '-118.54259'), ('34.00501', '-118.81009'), ('34.05223', '-118.24368'), ('26.0112', '-80.14949'), ('34.05223', '-118.24368'), ('34.05223', '-118.24368'), ('51.33111', '-2.27389'), ('34.05223', '-118.24368'), ('34.05223', '-118.24368'), ('26.0112', '-80.14949'), ('34.05223', '-118.24368')]
#
# ['brooklyn', 'new york city', 'new york', 'usa', 'manhattan', 'new york city', 'new york', 'usa', 'trump taj mahal casino and resort - 1000 boardwalk at virginia avenue', 'atlantic city', 'new jersey', 'usa']
# [('41.43977', '-81.73541'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('39.36428', '-74.42293')]
#
# ['atlanta', 'georgia', 'usa', 'washington', 'district of columbia', 'usa', 'usa']
# [('40.25948', '-89.23342')]
#
# ['budapest', 'hungary', 'hungary']
# [('47.49801', '19.03991')]
#
# ['colorado springs', 'colorado', 'usa']
# [('38.83388', '-104.82136')]
#
# ['winnipeg', 'manitoba', 'canada']
# [('49.8844', '-97.14704')]
#
# ['zumaya', 'guip\xc3\xbazcoa', 'pa\xc3\xads vasco', 'spain', 'donostia-san sebasti\xc3\xa1n', 'guip\xc3\xbazcoa', 'pa\xc3\xads vasco', 'spain', 'zarautz', 'guip\xc3\xbazcoa', 'pa\xc3\xads vasco', 'spain', 'getaria', 'guip\xc3\xbazcoa', 'pa\xc3\xads vasco', 'spain', 'sevilla', 'andaluc\xc3\xada', 'spain', 'leitza', 'navarra', 'spain']
# [('43.28444', '-2.16992'), ('43.30326', '-2.20444'), ('9.70383', '124.04829'), ('4.17061', '-76.16641'), ('43.08333', '-1.91667')]
#
# ['france']
# []
#
# ['delhi', 'india', 'new york', 'usa']
# [('37.43216', '-120.77854')]
#
# ['lowestoft', 'suffolk', 'england', 'uk', 'beccles', 'suffolk', 'england', 'uk']
# [('52.4752', '1.75159'), ('36.72836', '-76.58496'), ('34.54426', '-91.96903'), ('52.45936', '1.56465'), ('36.72836', '-76.58496'), ('34.54426', '-91.96903')]
#
# ['providence', 'rhode island', 'usa']
# [('41.82399', '-71.41283')]
#
# ['florida', 'usa']
# []
#
# ['buffalo', 'new york', 'usa', 'niagara falls', 'new york', 'usa', 'lockport', 'new york', 'usa']
# [('38.61759', '-81.9818'), ('43.0945', '-79.05671'), ('43.17061', '-78.69031')]
#
# ['istanbul', 'turkey']
# []
#
# ['bangkok', 'thailand', 'tokyo', 'japan']
# [('13.75398', '100.50144'), ('35.6895', '139.69171')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['campinas', 's\xc3\xa3o paulo', 'brazil', 'campinas', 's\xc3\xa3o paulo', 'brazil']
# [('-22.90556', '-47.06083'), ('-23.5475', '-46.63611'), ('-22.90556', '-47.06083'), ('-23.5475', '-46.63611')]
#
# ['kathmandu', 'nepal', 'hemja', 'kaski', 'nepal']
# [('27.70169', '85.3206')]
#
# ['kassel', 'hessen', 'germany', 'vellmar', 'hessen', 'germany', 'burg trendelburg', 'trendelburg', 'hessen', 'germany']
# [('51.31667', '9.5'), ('51.35806', '9.47974'), ('51.57408', '9.42095')]
#
# ['tom\xc3\xa9', 'concepci\xc3\xb3n', 'viii regi\xc3\xb3n', 'chile']
# [('-36.61756', '-72.95593'), ('-27.34127', '-65.59636')]
#
# ['yalova', 'turkey']
# [('40.65501', '29.27693')]
#
# ['ahmedabad', 'gujarat', 'india']
# ...
# [('32.54208', '-97.32085'), ('32.34764', '-97.38668'), ('32.23459', '-97.75531'), ('38.15575', '-121.69134')]
#
# ['chengdu', 'china']
# [('30.66667', '104.06667')]
#
# ['long island', 'new york', 'usa', 'new york', 'usa', 'westchester', 'bronx', 'new york city', 'new york', 'usa']
# [('41.85059', '-87.882'), ('40.71427', '-74.00597')]
#
# ['leba', 'pomorskie', 'poland', 'slowinski park narodowy', 'pomorskie', 'poland', 'bangaluu club', 'berlin', 'germany', 'berlin', 'germany', 'paretz', 'brandenburg', 'germany', 'potsdam', 'brandenburg', 'germany']
# [('32.2655', '106.67809'), ('44.46867', '-71.18508'), ('44.46867', '-71.18508'), ('37.99896', '-86.16941'), ('52.39886', '13.06566'), ('37.99896', '-86.16941')]
#
# ['kiryu', 'gunma', 'japan']
# []
#
# ['clark fork', 'idaho', 'usa', "coeur d'alene", 'idaho', 'usa', 'sandpoint', 'idaho', 'usa']
# [('47.67768', '-116.78047'), ('48.27659', '-116.55325')]
#
# ['los angeles', 'california', 'usa', 'morgue prop rentals - 5134 valley boulevard', 'los angeles', 'california', 'usa']
# [('34.05223', '-118.24368'), ('34.05223', '-118.24368')]
#
# ['new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['chicago', 'illinois', 'usa']
# [('41.85003', '-87.65005')]
#
# ['kolkata', 'west bengal', 'india']
# [('22.56263', '88.36304')]
#
# ['mexico']
# []
#
# ['new castle', 'washington', 'usa', 'seattle', 'washington', 'usa']
# [('43.07231', '-70.71616'), ('47.60621', '-122.33207')]
#
# ['buena vista', 'bolivia', 'cochabamba', 'bolivia', 'tarija', 'bolivia']
# [('19.04278', '-96.85667'), ('-9.49361', '-77.85944'), ('-21.53549', '-64.72956')]
#
# ['philmont', 'new york', 'usa']
# [('42.24842', '-73.65318')]
#
# ['indianapolis', 'indiana', 'usa', 'muncie', 'indiana', 'usa']
# [('39.76838', '-86.15804'), ('40.19338', '-85.38636')]
#
# ['tucson', 'arizona', 'usa']
# [('32.22174', '-110.92648')]
#
# ['canisteo', 'new york', 'usa', 'white plains', 'new york', 'usa']
# [('42.27035', '-77.60582'), ('35.23402', '-81.39814')]
#
# ['alexandria', 'egypt', 'cairo', 'egypt']
# [('45.88524', '-95.37754'), ('42.29897', '-73.99847')]
#
# ['binangonan', 'rizal', 'philippines', 'calumpang', 'binangonan', 'rizal', 'philippines', 'libis', 'binangonan', 'rizal', 'philippines']
# [('14.4646', '121.1929'), ('17.8486', '121.3466'), ('14.6228', '121.0897'), ('14.4646', '121.1929'), ('17.8486', '121.3466'), ('14.4646', '121.1929'), ('17.8486', '121.3466')]
#
# ['oakland', 'california', 'usa']
# [('34.1001', '-96.79389')]
#
# ['east village', 'manhattan', 'new york city', 'new york', 'usa', 'kaufman astoria studios - 3412 36th street', 'astoria', 'queens', 'new york city', 'new york', 'usa', 'manhattan', 'new york city', 'new york', 'usa', "grant's tomb", 'riverside drive', 'new york city', 'new york', 'usa', 'chinatown', 'manhattan', 'new york city', 'new york', 'usa', 'greenwich village', 'manhattan', 'new york city', 'new york', 'usa', 'new york city', 'new york', 'usa', 'queens', 'new york city', 'new york', 'usa']
# [('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('40.22754', '-90.35957'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597')]
#
# ['toronto', 'ontario', 'canada']
# [('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['santa clarita', 'california', 'usa', 'playboy mansion - 10236 charing cross road', 'holmby hills', 'los angeles', 'california', 'usa']
# [('34.39166', '-118.54259'), ('34.05223', '-118.24368')]
#
# ['las vegas', 'nevada', 'usa']
# [('9.53727', '-68.6296')]
#
# ['turkey']
# []
#
# ['new jersey', 'usa']
# []
#
# ['blue springs', 'missouri', 'usa', 'clinton', 'missouri', 'usa', 'springfield', 'missouri', 'usa']
# [('39.01695', '-94.28161'), ('46.76909', '-113.7126'), ('43.49507', '-72.03342')]
#
# ['australia']
# []
#
# ['salt lake city', 'utah', 'usa']
# [('40.76078', '-111.89105')]
#
# ['albuquerque', 'new mexico', 'usa', 'zia pueblo', 'new mexico', 'usa', 'new mexico', 'usa', 'beach', 'between sandcastle drive and beach access road 1a', 'port aransas', 'texas', 'usa', 'sandollar sity beach house rentals', 'port aransas', 'texas', 'usa', 'texas', 'usa']
# [('35.08449', '-106.65114'), ('46.91807', '-104.00437'), ('27.83392', '-97.0611'), ('27.83392', '-97.0611')]
#
# ['hamilton', 'ontario', 'canada', 'toronto', 'ontario', 'canada']
# [('-37.74425', '142.02202'), ('44.02655', '-116.96294'), ('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['kawasaki', 'kanagawa', 'japan', 'tokyo', 'japan']
# [('35.52056', '139.71722'), ('35.6895', '139.69171')]
#
# ['bay area', 'san francisco', 'california', 'usa', 'california', 'usa', 'jamestown', 'california', 'usa', 'oakland', 'california', 'usa', 'san francisco', 'california', 'usa', 'tuolumne city', 'california', 'usa']
# [('-20.71667', '-64.7'), ('-33.20531', '138.60503'), ('34.1001', '-96.79389'), ('-20.71667', '-64.7'), ('37.9627', '-120.2413')]
#
# ['toronto', 'ontario', 'canada']
# [('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['brooklyn', 'new york city', 'new york', 'usa', 'manhattan', 'new york city', 'new york', 'usa']
# [('41.43977', '-81.73541'), ('40.71427', '-74.00597'), ('40.78343', '-73.96625'), ('40.71427', '-74.00597')]
#
# ['austin', 'texas', 'usa', 'dripping springs', 'texas', 'usa', 'taylor', 'texas', 'usa', 'lockhart', 'texas', 'usa']
# [('34.99842', '-91.98376'), ('30.19021', '-98.08668'), ('30.57076', '-97.40944'), ('29.88494', '-97.67')]
#
# ['budapest', 'hungary', 'hungary']
# [('47.49801', '19.03991')]
#
# ['helsinki', 'finland', 'moscow', 'russia', 'rovaniemi', 'finland', 'france', 'kharkov', 'ukraine', 'kiev', 'ukraine', 'ukraine']
# [('60.16952', '24.93545'), ('55.75222', '37.61556'), ('66.5', '25.71667'), ('50.45466', '30.5238')]
#
# ['lyon', 'rh\xc3\xb4ne', 'rh\xc3\xb4ne-alpes', 'france']
# [('45.74846', '4.84671')]
#
# ['brisbane', 'queensland', 'australia', 'gold coast', 'queensland', 'australia', 'queensland maritime museum', 'south bank', 'brisbane', 'queensland', 'australia', 'southport spit', 'southport', 'queensland', 'australia', 'village roadshow studios', 'oxenford', 'queensland', 'australia', 'sydney', 'new south wales', 'australia']
# [('-27.46794', '153.02809'), ('-28.00029', '153.43088'), ('54.56667', '-1.15'), ('-27.46794', '153.02809'), ('41.13649', '-73.28345'), ('-27.89033', '153.31309'), ('46.1351', '-60.1831')]
#
# ['eugene', 'oregon', 'usa']
# [('44.05207', '-123.08675')]
#
# ['adelaide', 'south australia', 'australia', 'south australia', 'australia']
# [('-32.70747', '26.29564')]
#
# ['bangkok', 'thailand', 'chicago', 'illinois', 'usa']
# [('13.75398', '100.50144'), ('41.85003', '-87.65005')]
#
# ['clifton', 'new jersey', 'usa', 'middletown', 'new jersey', 'usa', 'red bank', 'new jersey', 'usa', 'staten island', 'new york city', 'new york', 'usa']
# [('52.0399', '-0.30051'), ('39.02761', '-78.28056'), ('35.11229', '-85.29413'), ('40.56233', '-74.13986'), ('40.71427', '-74.00597')]
#
# ['mumbai', 'maharashtra', 'india']
# [('19.07283', '72.88261')]
#
# ['cozumel island', 'canc\xc3\xban', 'benito ju\xc3\xa1rez', 'quintana roo', 'mexico', 'lawrence', 'kansas', 'usa']
# [('21.17429', '-86.84656'), ('-37.67188', '-59.80653'), ('20.86946', '-88.63153'), ('39.83865', '-86.02526')]
#
# ['san juan', 'puerto rico']
# [('-21.26667', '-65.3')]
#
# ['brackettville', 'texas', 'usa']
# [('29.31051', '-100.41786')]
#
# ['s\xc3\xa3o paulo', 's\xc3\xa3o paulo', 'brazil']
# [('-23.5475', '-46.63611'), ('-23.5475', '-46.63611')]
#
# ['brazil', 'rio de janeiro', 'brazil']
# [('-22.90278', '-43.2075')]
#
# ['hillsboro', 'new mexico', 'usa', 'truth or consequences', 'new mexico', 'usa']
# [('32.45931', '-89.51146'), ('33.1284', '-107.25281')]
#
# ['malacca', 'malaysia', 'singapore']
# [('2.196', '102.2405')]
#
# ['crafton', 'pennsylvania', 'usa', 'washington', 'pennsylvania', 'usa', 'homestead', 'pennsylvania', 'usa', 'pittsburgh', 'pennsylvania', 'usa', 'soldiers and sailors museum and memorial - 4141 fifth avenue', 'pittsburgh', 'pennsylvania', 'usa']
# [('40.43507', '-80.06617'), ('40.4059', '-79.91199'), ('40.44062', '-79.99589'), ('40.44062', '-79.99589')]
#
# ['new orleans', 'louisiana', 'usa']
# [('29.95465', '-90.07507')]
#
# ['tennessee', 'usa', 'washington', 'usa']
# []
#
# ['geyserville', 'california', 'usa', 'los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['cologne', 'north rhine-westphalia', 'germany', 'knokke', 'belgium']
# [('44.77163', '-93.78135')]
#
# ['la jolla', 'san diego', 'california', 'usa']
# [('32.84727', '-117.2742'), ('10.25982', '-67.9533')]
#
# ['havertown', 'pennsylvania', 'usa', 'south philadelphia', 'pennsylvania', 'usa', 'wayne', 'pennsylvania', 'usa']
# [('44.34868', '-70.06616')]
#
# ['bristol', 'pennsylvania', 'usa']
# [('41.72144', '-85.81749')]
#
# ['maupin', 'oregon', 'usa', 'portland', 'oregon', 'usa']
# [('36.58171', '-86.51638')]
#
# ['bryn mawr', 'pennsylvania', 'usa', 'haverford', 'pennsylvania', 'usa', 'ardmore', 'pennsylvania', 'usa', 'bryn mawr college - 101 n. merion avenue', 'bryn mawr', 'pennsylvania', 'usa', "friends' central school", 'wynnewood', 'pennsylvania', 'usa', 'philadelphia', 'pennsylvania', 'usa']
# [('40.01983', '-75.30463'), ('34.99203', '-86.84695'), ('40.01983', '-75.30463'), ('34.64342', '-97.16447'), ('44.1545', '-75.70882')]
#
# ['hyvink\xc3\xa4\xc3\xa4', 'finland', 'kartanonkoski', 'vantaa', 'finland', 'kauklahti', 'espoo', 'finland', 'porvoo', 'finland']
# [('60.29414', '25.04099'), ('60.2052', '24.6522'), ('60.39233', '25.66507')]
#
# ['idaho', 'usa', "coeur d'alene", 'idaho', 'usa']
# [('47.67768', '-116.78047')]
#
# ['lisbon', 'portugal', 'tobis portuguesa', 'lumiar', 'lisbon', 'portugal']
# [('41.92112', '-91.38545'), ('41.92112', '-91.38545')]
#
# ['nago', 'okinawa', 'japan']
# [('26.61502', '127.98543'), ('26.33583', '127.80139')]
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['budapest', 'hungary', 'bulgaria', 'debrashtitza', 'bulgaria']
# [('47.49801', '19.03991')]
#
# ['canadian motion picture park studios', 'burnaby', 'british columbia', 'canada', 'bloedel floral conservatory', 'vancouver', 'british columbia', 'canada', 'british columbia institute of technology', 'burnaby', 'british columbia', 'canada', 'burnaby', 'british columbia', 'canada', 'marine building - 355 burrard street', 'vancouver', 'british columbia', 'canada', 'nat bailey stadium', 'vancouver', 'british columbia', 'canada', 'new westminster', 'british columbia', 'canada', 'old terminal pub', 'new westminster', 'british columbia', 'canada', 'riverview hospital', 'coquitlam', 'british columbia', 'canada', 'vancouver', 'british columbia', 'canada', 'tanex industries', 'new westminster', 'british columbia', 'canada']
# [('49.26636', '-122.95263'), ('45.63873', '-122.66149'), ('49.26636', '-122.95263'), ('49.26636', '-122.95263'), ('45.63873', '-122.66149'), ('45.63873', '-122.66149'), ('49.20678', '-122.91092'), ('49.20678', '-122.91092'), ('49.28297', '-122.75262'), ('45.63873', '-122.66149'), ('49.20678', '-122.91092')]
#
# ['barcelona', 'catalonia', 'spain', 'copenhagen', 'denmark', 'gothenburg', 'v\xc3\xa4stra g\xc3\xb6talands l\xc3\xa4n', 'sweden', 'malm\xc3\xb6', 'sk\xc3\xa5ne l\xc3\xa4n', 'sweden']
# [('41.38879', '2.15899'), ('55.67594', '12.56553'), ('40.92945', '-100.16068'), ('55.60587', '13.00073')]
#
# ['east london', 'london', 'england', 'uk', 'isle of man', 'kennaa studios', 'isle of man']
# [('-33.01529', '27.91162'), ('35.32897', '-93.25296'), ('34.54426', '-91.96903')]
#
# ['ashikaga', 'tochigi', 'japan']
# [('36.33333', '139.45'), ('36.38333', '139.73333')]
#
# ['bras\xc3\xadlia', 'distrito federal', 'brazil']
# [('-15.77972', '-47.92972')]
#
# ['turkey', 'denmark', 'greece', 'norway', 'sarikamis', 'kars', 'turkey', 'sweden']
# [('40.59825', '43.08548')]
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['mexico']
# []
#
# ['suffolk', 'england', 'uk']
# [('36.72836', '-76.58496'), ('34.54426', '-91.96903')]
#
# ['brittany', 'france', "c\xc3\xb4tes-d'armor", 'france', 'gare montparnasse', 'place raoul dautry', 'paris 15', 'paris', 'france', 'mont saint-michel', 'saint-rivoal', 'finist\xc3\xa8re', 'france', 'paris 14', 'paris', 'france', 'paris', 'france']
# [('36.302', '-88.32671'), ('36.302', '-88.32671'), ('36.302', '-88.32671')]
#
# ['desert studies center', 'zzzyzx', 'california', 'usa', 'baker', 'california', 'usa', 'los angeles', 'california', 'usa', 'playa del rey', 'los angeles', 'california', 'usa', 'santa clarita studios - 25135 anza drive', 'santa clarita', 'california', 'usa', 'soda lake', 'zzyzx', 'california', 'usa']
# [('30.58824', '-91.16816'), ('34.05223', '-118.24368'), ('34.05223', '-118.24368'), ('34.39166', '-118.54259')]
#
# ['luton hoo estate', 'luton', 'bedfordshire', 'england', 'uk', 'three mills studios', 'three mill lane', 'bow', 'london', 'england', 'uk']
# [('51.87967', '-0.41748'), ('34.54426', '-91.96903'), ('35.32897', '-93.25296'), ('34.54426', '-91.96903')]
#
# ['half moon bay', 'california', 'usa', 'south lake tahoe', 'california', 'usa']
# [('37.46355', '-122.42859'), ('38.93324', '-119.98435')]
#
# ['dresden', 'saxony', 'germany', 'jena', 'thuringia', 'germany']
# [('40.12146', '-82.01069'), ('50.92878', '11.5899')]
#
# ['paris', 'france']
# [('36.302', '-88.32671')]
#
# ['city island', 'bronx', 'new york city', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['chaco', 'argentina', 'formosa', 'argentina', 'san juan', 'argentina']
# [('-26.17753', '-58.17814'), ('-21.26667', '-65.3')]
#
# ['san francisco', 'california', 'usa']
# [('-20.71667', '-64.7')]
#
# ['eskisehir', 'turkey']
# []
#
# ['melbourne', 'victoria', 'australia', 'sydney', 'new south wales', 'australia']
# [('53.88755', '-0.85925'), ('15.5775', '120.6822'), ('46.1351', '-60.1831')]
#
# ['constanta', 'romania', 'romania']
# []
#
# ['bulgaria']
# []
#
# ['himachal pradesh', 'india', 'mumbai', 'maharashtra', 'india']
# [('19.07283', '72.88261')]
#
# ['minneapolis', 'minnesota', 'usa', 'st. louis park', 'minnesota', 'usa']
# [('39.12194', '-97.7067')]
#
# ['paris', 'france']
# [('36.302', '-88.32671')]
#
# ['three mills studios', 'three mill lane', 'bow', 'london', 'england', 'uk', 'england', 'uk']
# [('35.32897', '-93.25296'), ('34.54426', '-91.96903'), ('34.54426', '-91.96903')]
#
# ['orlando', 'florida', 'usa']
# [('28.53834', '-81.37924')]
#
# ['burkeville', 'british columbia', 'canada', 'delta', 'british columbia', 'canada', 'new westminster', 'british columbia', 'canada', 'vancouver', 'british columbia', 'canada']
# [('49.14399', '-122.9068'), ('49.20678', '-122.91092'), ('45.63873', '-122.66149')]
#
# ['new york city', 'new york', 'usa', 'new york', 'usa']
# [('40.71427', '-74.00597')]
#
# ['los angeles', 'california', 'usa']
# [('34.05223', '-118.24368')]
#
# ['buenos aires', 'federal district', 'argentina']
# [('8.41384', '-81.4844')]
#
# ['erlangen', 'bavaria', 'germany', 'hungary', 'ljubljana', 'slovenia', 'nuremberg', 'bavaria', 'germany', 'romania', 'venice', 'veneto', 'italy']
# [('49.59099', '11.00783'), ('46.05108', '14.50513'), ('38.67227', '-90.16983')]
#
# ['toronto', 'ontario', 'canada']
# [('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['aussois', 'savoie', 'france']
# []
#
# ['los angeles', 'california', 'usa', 'san francisco', 'california', 'usa']
# [('34.05223', '-118.24368'), ('-20.71667', '-64.7')]
#
# ['le bic', 'qu\xc3\xa9bec', 'canada', 'moncton', 'new brunswick', 'canada']
# [('46.81228', '-71.21454'), ('46.09454', '-64.7965'), ('40.48622', '-74.45182')]
#
# ['yogyakarta', 'indonesia']
# [('-7.78278', '110.36083')]
#
# ['attitude studios', 'luxembourg', 'luxembourg', 'duncan studio', 'los angeles', 'california', 'usa', 'starz animation', 'toronto', 'ontario', 'canada']
# [('34.05223', '-118.24368'), ('43.70011', '-79.4163'), ('44.02655', '-116.96294')]
#
# ['shanghai', 'china', 'woodville', 'texas', 'usa']
# [('31.22222', '121.45806'), ('31.10462', '-91.29956')]
#
# ['brooklyn', 'new york city', 'new york', 'usa', 'javits federal office building - 26 federal plaza', 'new york city', 'new york', 'usa', 'new york city', 'new york', 'usa']
# [('41.43977', '-81.73541'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597'), ('40.71427', '-74.00597')]
#
# ['stuttgart', 'baden-w\xc3\xbcrttemberg', 'germany', 'tangiers', 'tangier-t\xc3\xa9touan', 'morocco']
# [('48.78232', '9.17702')]

# %%
#print duplicatecities[:30]
print 'italy' in duplicatecities
print coordinatesdict['moscow']

# %%
df_boolean[:10]

# %%
print len(citiesflatten)
cityflattenset = set(citiesflatten)

# %%
print city_coordinates

# %%
separated_cities = []
coordinates = []
for x in range(len(df_boolean)):
    temp = df_boolean['separated_places'][x]
    templist = []
    coordinatestemp = []
    for y in range(len(temp)):
        if temp[y] in citiesflatten:
            templist.append(temp[y])   

    #print templist
    #print temp
    #print
    separated_cities.append(templist)
    coordinates.append(coordinatestemp)
    if (x%100) == 0:
        print x
    
df_boolean["separated_cities"] = separated_cities
df_boolean["coordinates"] = coordinates

# %%
import codecs
cities2raw = []
with codecs.open('tempdata/CountriesToCities.json', 'r', encoding= "UTF-16") as f:
    for line in f:
       cities2raw.append(json.loads(line))

# %%
#print cities2raw

# %%
cities2 = cities2raw[0].values()

# %%
citiesflatten = [item.lower() for sublist in cities2 for item in sublist]

# %%
print len(citiesflatten)

# %%
test = "Egypt"
for key in cities2raw[0]:
    if test in cities2raw[0][key]:
        print key

# %%
df_boolean.head(10)

# %%
df_boolean.to_csv('df_boolean_temp.csv',sep=',',encoding='utf-8')

# %%
places3 = set()
places3_freq = {}
for row in df_boolean["separated_cities"]:
    for loc in row:
        places3.add(loc)
        #split = loc.split(",")
        #for item in split:
        #    stripped = item.encode('utf8').strip().lower()
        #    if stripped!="":
        if stripped not in places3_freq.keys():
            places3_freq[stripped] = 1
        places3_freq[stripped] = places3_freq[stripped] + 1
print len(places3)

# %%
for place in places2:
        df_boolean[place] = [place in location for location in df_boolean.separated_cities]

# %% [markdown]
# #3. Filbert: run from here onwards

# %%
new_df_input = pd.read_csv('df_boolean_temp2.csv',sep=',',encoding='utf-8')

# %%
#new_df_input.drop('level_0', axis=1, inplace=True)
new_df_input.drop('Unnamed: 0', axis=1, inplace=True)
new_df_input.head()

# %%
coordinateslist = []
coordinates_cities = []
for entry in df_boolean['separated_places']:
    print entry

    coordinateslist.append([coordinatesdict[x] for x in entry if x in coordinatesdict])
    coordinates_cities.append([x for x in entry if x in coordinatesdict])
    print coordinateslist
    
df_boolean['coordinates'] = coordinateslist
df_boolean['coordinates_cities'] = coordinates_cities

# %%
new_df_input.head()

# %%
new_df_input.to_csv('df_boolean_temp3.csv',sep=',',encoding='utf-8')

# %%
--------------------------------------------------------------------------

# %%
new_df_input.head()

# %%
old_df = new_df_input.copy()
del old_df['coordinates']
del old_df['coordinates_cities']
old_df.head()

# %%
for x in range(10):
#for x in range(len(new_df_input)):    
    coordinateslist = new_df_input.iloc[x]['coordinates'][2:-2].split('), ')
    coordinateslist = set([item.replace('(', '') for item in coordinateslist])
    coordinatescities = set(new_df_input.iloc[x]['coordinates_cities'][1:-1].split(', '))
    print coordinateslist
    print coordinatescities
    #print x
    assert len(coordinateslist) == len(coordinatescities)

# %%
def dedupe(items):
    seen = set()
    for item in items:
        if item not in seen:
            yield item
            seen.add(item)

# %%
print list(dedupe(new_df_input.iloc[7276]['coordinates'][2:-2].split('), (')))
print list(dedupe(new_df_input.iloc[7276]['coordinates_cities'][1:-1].split(', ')))
print
print new_df_input.iloc[7276]['coordinates_cities'][1:-1].split(', ')
#print new_df_input.iloc[7276]['coordinates'][2:-2]

# %%
#Get set of unique cities

def unique_entries(input_df, field):
    entries = set()
    for row in input_df[field]:
        for loc in row:
            entries.add(loc)
    return entries

#clean the column by removing brackets from the reads
def clean_column(input_df, field):
    cleanedrowlist = []
    for row in input_df[field]:
        cleanedrow =  row.replace('[', '')
        cleanedrow =  cleanedrow.replace(']', '')
        cleanedrow = cleanedrow.split(", ")
        cleanedrowlist.append(cleanedrow)
    input_df[field] = cleanedrowlist

# %%
newdf_boolean = new_df_input.copy()
clean_column(newdf_boolean, "separated_cities")
clean_column(newdf_boolean, "genre")

# %%
places2 = unique_entries(newdf_boolean, "separated_cities")
places2.remove("")
places2.remove("...")
print len(places2)

# %%
genres = unique_entries(newdf_boolean, "genre")
genres.remove("")
print len(genres) 
print genres

# %%
PCAdf = pd.DataFrame()
#create a column for each city, and set to true if that row contains that city
for place in places2:
        PCAdf[place] = [place in location for location in newdf_boolean.separated_cities]
for genre in genres:
        PCAdf[genre] = [genre in genre_entries for genre_entries in newdf_boolean.genre]

# %%
PCAdf = PCAdf.astype(int)
PCAdf

# %%
#random sample of 6000 rows
random.seed(10)

SAMPLESIZE = 10000

newdf_boolean_sampled = new_df_input.copy()
clean_column(newdf_boolean_sampled, "separated_cities")
clean_column(newdf_boolean_sampled, "genre")

rows = random.sample(newdf_boolean_sampled.index, SAMPLESIZE)
newdf_boolean_sampled = newdf_boolean_sampled.ix[rows]

# %%
places3 = unique_entries(newdf_boolean_sampled, "separated_cities")
if "" in places3:
    places3.remove("")
if "..." in places3:
    places3.remove("...")
print len(places3)

# %%
genres3 = unique_entries(newdf_boolean_sampled, "genre")
genres3.remove("")
print len(genres3) 
print genres3

# %%
PCAsampleddf = pd.DataFrame()
#create a column for each city, and set to true if that row contains that city
for place in places3:
        PCAsampleddf[place] = [place in location for location in newdf_boolean_sampled.separated_cities]
for genre in genres3:
        PCAsampleddf[genre] = [genre in genre_entries for genre_entries in newdf_boolean_sampled.genre]

# %%
PCAsampleddf = PCAsampleddf.astype(int)
PCAsampleddf

# %%
freq = PCAsampleddf[PCAsampleddf.columns[:-len(genres3)]].sum(axis=0)
sortfreq = freq.sort_values(ascending=False)
print sortfreq[0:15]
ax=(sortfreq[0:9]).plot('barh')
ax.invert_yaxis()

# %% [markdown]
# ## Get Rating DF

# %%
def get_median(input_df):
    rating_list = []
    for x in input_df["user_ratings"]:
        if isinstance(x, (np.ndarray, np.generic) ):
            rating_list.append(x)

    print np.mean(rating_list)
    ratingmedian = np.median(rating_list)
    print ratingmedian
    return ratingmedian

# %%
def get_ratingdf(inputdf):
    ratingsdf = pd.DataFrame()
    #ratingmedian = get_median(inputdf)
    ratingmedian = 5
    ratingslist = []
    for x in range(len(inputdf)):
        if inputdf["user_ratings"].iloc[x] >= ratingmedian:
            ratingslist.append(1)
        else:
            ratingslist.append(0)
    ratingsdf["fresh"] = ratingslist
    return ratingsdf

# %%
ratingsdf = get_ratingdf(newdf_boolean)
ratingsdf_sampled = get_ratingdf(newdf_boolean_sampled)
#print ratingsdf_sampled.head()

# %% [markdown]
# # PCA on size 10,000 data set

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=1500)

#X should consist only of independent variables, leave out Y
new_X = pca.fit_transform(PCAsampleddf)

# %%
pca.explained_variance_ratio_

# %%
print pca.explained_variance_ratio_.sum()

# %%
Xdf = pd.DataFrame()

for i in range(pca.explained_variance_ratio_.shape[0]):
    Xdf["pc%i" % (i+1)] = new_X[:,i]

# %%
Xdf

# %% [markdown]
# # Split data

# %%
from sklearn.cross_validation import train_test_split
Xlr, Xtestlr, ylr, ytestlr = train_test_split(Xdf.values, ratingsdf_sampled['fresh'].values, train_size=0.75, random_state=1)

# %%
Xlr

# %% [markdown]
# # Baseline accuracy

# %% [markdown]
# We calculate a baseline accuracy by assuming that all the predictions were 'fresh'. This gives us a baseline of:

# %%
baseline  = sum(ytestlr)*1./len(ytestlr)
print 'baseline accuracy: %0.4f' % baseline

# %% [markdown]
# For our classifier to to worthwhile pursuing, the classifier's accuracy should be better than the baseline. This is what we will explore in the next few sections using logistic regression and KNN.

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

clf=LogisticRegression()
parameters = {"C": [0.0001, 0.001, 0.1, 1, 10, 100]}
fitmodel = GridSearchCV(clf, param_grid=parameters, cv=5, scoring="accuracy")
fitmodel.fit(Xlr, ylr)
fitmodel.best_estimator_, fitmodel.best_params_, fitmodel.best_score_, fitmodel.grid_scores_

# %%
clflog=LogisticRegression(C=fitmodel.best_params_['C'])
clflog.fit(Xlr, ylr)
train_accuracy = clflog.score(Xlr,ylr)
test_accuracy=clflog.score(Xtestlr,ytestlr)
print "Accuracy on training data: %0.4f" % (train_accuracy)
print "Accuracy on test data:     %0.4f" % (test_accuracy)

# %%
from sklearn.metrics import roc_curve, auc
def make_roc(name, clf, ytest, xtest, ax=None, labe=5, proba=True, skip=0):
    initial=False
    if not ax:
        ax=plt.gca()
        initial=True
    if proba:#for stuff like logistic regression
        fpr, tpr, thresholds=roc_curve(ytest, clf.predict_proba(xtest)[:,1])
    else:#for stuff like SVM
        fpr, tpr, thresholds=roc_curve(ytest, clf.decision_function(xtest))
    roc_auc = auc(fpr, tpr)
    if skip:
        l=fpr.shape[0]
        ax.plot(fpr[0:l:skip], tpr[0:l:skip], '.-', alpha=0.3, label='ROC curve for %s (area = %0.2f)' % (name, roc_auc))
    else:
        ax.plot(fpr, tpr, '.-', alpha=0.3, label='ROC curve for %s (area = %0.2f)' % (name, roc_auc))
    label_kwargs = {}
    label_kwargs['bbox'] = dict(
        boxstyle='round,pad=0.3', alpha=0.2,
    )
    if labe!=None:
        for k in xrange(0, fpr.shape[0],labe):
            #from https://gist.github.com/podshumok/c1d1c9394335d86255b8
            threshold = str(np.round(thresholds[k], 2))
            ax.annotate(threshold, (fpr[k], tpr[k]), **label_kwargs)
    if initial:
        ax.plot([0, 1], [0, 1], 'k--')
        ax.set_xlim([0.0, 1.0])
        ax.set_ylim([0.0, 1.05])
        ax.set_xlabel('False Positive Rate')
        ax.set_ylabel('True Positive Rate')
        ax.set_title('ROC')
    ax.legend(loc="lower right")
    return ax

# %%
with sns.hls_palette(8, l=.3, s=.8):
    ax=make_roc("logistic-regression",clflog, ytestlr, Xtestlr, labe=200, skip=50)

# %% [markdown]
# # kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

clf= KNeighborsClassifier()
k = {}

# %%
#coarse grain search
gs = GridSearchCV(KNeighborsClassifier(), param_grid={"n_neighbors": range(1,86,20)}, cv=5)
gs.fit(Xlr, ylr)
gs.best_params_, fitmodel.best_score_, fitmodel.grid_scores_
for scores in gs.grid_scores_:
    k[scores[1]] = (scores[0])['n_neighbors']
k_best = k[max(k.keys())]

# %%
#fine grain search
gs = GridSearchCV(KNeighborsClassifier(), param_grid={"n_neighbors": range(k_best-8,k_best+8,2)}, cv=5)
gs.fit(Xlr, ylr)
gs.best_params_, fitmodel.best_score_, fitmodel.grid_scores_
for scores in gs.grid_scores_:
    k[scores[1]] = (scores[0])['n_neighbors']

# %%
k

# %%
k_best = k[max(k.keys())]
k_best

# %%
#clfknn=KNeighborsClassifier(n_neighbors=k_best)
clfknn=KNeighborsClassifier(n_neighbors=83)
clfknn = clfknn.fit(Xlr, ylr)
train_accuracy = clflog.score(Xlr,ylr)
test_accuracy = clfknn.score(Xtestlr,ytestlr)
print "Accuracy on training data: %0.4f" % (train_accuracy)
print "Accuracy on test data:     %0.4f" % (test_accuracy)

# %%
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

# %%
def points_plot(ax, Xtr, Xte, ytr, yte, clf, mesh=True, colorscale=cmap_light, cdiscrete=cmap_bold, alpha=0.1, psize=10, zfunc=False, predicted=False):
    h = .02
    X=np.concatenate((Xtr, Xte))
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))

    #plt.figure(figsize=(10,6))
    if zfunc:
        p0 = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 0]
        p1 = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
        Z=zfunc(p0, p1)
    else:
        Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    ZZ = Z.reshape(xx.shape)
    if mesh:
        plt.pcolormesh(xx, yy, ZZ, cmap=cmap_light, alpha=alpha, axes=ax)
    if predicted:
        showtr = clf.predict(Xtr)
        showte = clf.predict(Xte)
    else:
        showtr = ytr
        showte = yte
    ax.scatter(Xtr[:, 0], Xtr[:, 1], c=showtr-1, cmap=cmap_bold, s=psize, alpha=alpha,edgecolor="k")
    # and testing points
    ax.scatter(Xte[:, 0], Xte[:, 1], c=showte-1, cmap=cmap_bold, alpha=alpha, marker="s", s=psize+10)
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    return ax,xx,yy

# %%
plt.figure()
ax=plt.gca()
points_plot(ax, Xtrain, Xtest, ytrain, ytest, clf, alpha=0.3, psize=20)
